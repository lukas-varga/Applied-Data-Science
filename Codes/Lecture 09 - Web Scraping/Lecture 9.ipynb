# %% [markdown]
# ## Lecture 9 - Data - Web scrapping HTML, JSON and XML
#
# Web Scraping is the process of obtainin data from websites and structuring the data into a useable format.
#
# First lets get a connection status from a a website, we will use the following site and query information:
#
# ``https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia``
#
# What we are wanting to obtain is a status 200 which indicates a successful HTTP connection.

# %%
import requests

url ='https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia'
page =requests.get(url)
print(page.status_code)
# Out:
# 200

# %% [markdown]
# ### Extracting HTML Data
#
# In this next example we will look at extracting the HTML data. We will use the following URL:
#
# ``https://www.university-list.net/New-Zealand/universities-1000.htm``

# %%
import requests
from bs4 import BeautifulSoup

university_url = "https://www.university-list.net/New-Zealand/universities-1000.htm"

# %%
university_url
# Out:
# 'https://www.university-list.net/New-Zealand/universities-1000.htm'

# %% [markdown]
# Lets check our requests status

# %%
page = requests.get(university_url)
print(page)
# Out:
# <Response [200]>

# %% [markdown]
# Lets examine the html page text it may not look to be in the prettiest of states at present.

# %%
print(page.text)
# Out:
# <!doctype html>
# <html lang="en"><!-- InstanceBegin template="/Templates/eng.dwt" codeOutsideHTMLIsLocked="false" -->
# <head>
# <meta charset="utf-8">
# <meta name=viewport content="width=device-width, initial-scale=1.0">
# <link href="../css/css.css" rel="stylesheet" type="text/css">
# <!--menu.jså¨åºé¨-->
# <!-- IEè»å­è½¯ä»¶å¼å§ -->
# <!â[if lt IE 9]>
# <script src="../js/polyfill.js"></script>
# <![endif]â>
# <!-- IEè»å­è½¯ä»¶ç»æ -->
# <!-- auto-adså¼å§ -->
# <script data-ad-client="ca-pub-2375604138158108" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- auto-adsç»æ -->
# <!-- InstanceBeginEditable name="doctitle" -->
# <link rel="amphtml" href="https://m.university-list.net/New-Zealand/universities-1000.htm" /><!--å¯¹åºçç§»å¨ç½é¡µ-->
# <!--<link rel="canonical" href="https://www.university-list.net/New-Zealand/universities-1000.htm" /><!--ææé¦éç½å-->
# <title>List of Universities and Colleges in New Zealand (36 Schools) - Education Rankings</title>
# <meta name="description" content="List of Universities and Colleges in New Zealand (36 Schools) - Education Rankings. This website provides useful information of studying abroad in main English Countries such as the US, Canada, the UK, Australia, New Zealand and Ireland.">
# <meta name="keywords" content="Universities, Colleges, New Zealand">
# <!-- InstanceEndEditable -->
# <!-- InstanceBeginEditable name="head" --><!-- InstanceEndEditable -->
# </head>
# <body>
# <div id="top"><a name="top" id="top"></a>
# <marquee scrollamount="2">
# <!-- InstanceBeginEditable name="EditRegion3" -->List of Universities and Colleges in New Zealand (36 Schools)<!-- InstanceEndEditable -->
# </marquee>
# </div>
# <div id="wrapper">
# <header>
# <div id="subnav1">
# <div class="menu" onClick="MM_showHideLayers('left','','show')">Open Menu</div>
# <div class="version"><!-- InstanceBeginEditable name="EditRegion4" --><a href="../xinxilan/daxue-1000.htm">Chinese&nbsp;<img src="../Images/chin.gif" alt="Chinese Version" width="36" height="23" border="0" align="absmiddle"></a><!-- InstanceEndEditable -->&nbsp;</div>
# </div>
# <div id="banner" role="banner"><!-- InstanceBeginEditable name="EditRegion5" -->List of Universities and Colleges in New Zealand<!-- InstanceEndEditable --></div>
# <div id="subnav2"><!-- InstanceBeginEditable name="EditRegion6" --><a href="../index.htm">Home Page </a>&gt;&gt; <a href="universities-1000.htm" title="Universities in New Zealand">Universities in New Zealand</a><!-- InstanceEndEditable --></div>
# </header>
# <div id="middle">
# <div id="left">
# <div class="closemenu" onClick="MM_showHideLayers('aside','','hide');MM_showHideLayers('left','','hide')">* Close Menu <img src="../Images/arrow.jpg" width="20" height="18"></div>
# <ul>
# <li><a href="../index.htm" title="Home Page" ><b>Home&nbsp;Page</b></a></li>
# <p><b>World:</b></p>
# <li><a href="../rank/univ-100000.html" title="Rankings of Universities Worldwide"> World University Rankings by Subject</a></li>
# <li><a href="../rank.htm"  title="Rankings of Universities Worldwide"> Top  Universities Worldwide</a></li>
# <p><strong><a href="../us/index.html" >US:</a></strong></p>
# <li><a href="../us/universities-0000.htm"  title="List of Universities in US"> List of Universities in US </a></li>
# <li><a href="../us/rank/univ-0000.htm" title="Rankings of Universities in US"> Rankings of Universities in US</a></li>
# <li><a href="../us/language/school-100000.html" title="English Language Schools in US "> Language Schools in US </a></li>
# <li><a href="../us/rank/school-100000.html" title="Rankings of High Schools in US in US ">Rankings of High Schools in US</a></li>
# <p><b>Canada:</b></p>
# <li><a href="../canada/universities-1000.htm"  title="List of Universities in Canada"> List of Universities in Canada</a></li>
# <li><a href="../canada/rank-1.htm" title="Rankings of Universities in Canada"> Rankings of Universities in Canada</a></li>
# <li><a href="../canada/language/school-100000.html" title="English Language Schools in Canada"> Language Schools in Canada </a></li>
# <p><b>UK:</b></p>
# <li><a href="../uk/universities-1000.html" title="List of Universities in UK"> List of Universities in UK</a></li>
# <li><a href="../uk/rank/univ-0000.htm" title="Rankings of Universities in UK"> Rankings of Universities in UK</a></li>
# <li><a href="../uk/language/school-100000.html" title="English Language Schools in the UK "> Language Schools in UK </a></li>
# <li><a href="../uk/rank/school-100000.html" title="Rankings of High Schools in UK "> Rankings of High Schools in UK</a></li>
# <p><b>Australia:</b></p>
# <li><a href="../Australia/universities-1000.htm" title="List of Universities in Australia">List of Universities in Australia </a></li>
# <li><a href="../Australia/rank-1000.html" title="Rankings of Universities in Australia"> Rankings of Universities in Australia</a></li>
# <li><a href="../Australia/language/school-100000.html" title="Language Schools in Australia"> Language Schools in Australia</a></li>
# <li><a href="../Australia/rank/school-100001.html" title="Rankings of High Schools in Australia "> Rankings of High Schools in Australia</a></li>
# <p><b>New Zealand:</b></p>
# <li><a href="universities-1000.htm" title="List of Universities in New Zealand"> List of Universities in New Zealand </a></li>
# <li><a href="rank-1000.html" title="Rankings of Universities in New Zealand"> Rankings of Universities in New Zealand</a></li>
# <li><a href="language/school-100000.html" title="Language Schools in New Zealand">Language Schools in New Zealand</a></li>
# <p><b>Ireland:</b></p>
# <li><a href="../Ireland/universities-1000.htm" title="List of Universities in Ireland"> List of Universities in Ireland </a></li>
# <li><a href="../Ireland/rank-1000.html" title="Rankings of Universities in Ireland"> Rankings of Universities in Ireland</a></li>
# <li><a href="../Ireland/language/school-100000.html" title="Language Schools in Ireland">Language Schools in Ireland</a></li>
# <p><b>Germany:</b></p>
# <li><a href="../germany/rank/univ-000000.html" title="Rankings of Universities in Germany"> Rankings of Universities in Germany</a></li>
# <p><b>China:</b></p>
# <li><a href="../china/rank/univ-100001.html" title="Rankings of Universities in China"> Rankings of Universities in China</a></li>
# <li><a href="../contact.htm" title="Contact Us"> Contact Us</a></li>
# <li><a href="../sitemap.html" > Sitemap in English</a></li>
# </ul>
# <div class="closemenu" onClick="MM_showHideLayers('aside','','hide');MM_showHideLayers('left','','hide')">* Close Menu <img src="../Images/arrow.jpg" width="20" height="18"></div>
# <div id="nav-qr-code">
# <p>QR CODE OF THIS SITE</p>
# <img src="../Images/QR-CODE02.gif" width="100" height="100">
# </div>
# </div>
# <div id="content" role="main">
# <!--search_english_up_start -->
# <script>
#   (function() {
#     var cx = '010108428344433716165:olhyzickubi';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = (document.location.protocol == 'https:' ? 'https:' : 'http:') +
#         '//cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
# </script>
# <gcse:search></gcse:search>
# <!--search_english_up_end -->
# <!-- InstanceBeginEditable name="EditRegion7" -->
# <h1><a href="universities-1000.htm"  title="List of Universities and Colleges in New Zealand (36 Schools)">List of Universities and Colleges in New Zealand (36 Schools)</a></h1>
# <div id="subnav3"><!--up-SubPageNav-start -->
# </div><!--up-SubPageNav-end -->
# <div align="center">
# <div class="ad-middle">
# <!--adsense_english_up_start-->
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Res-mob-en -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-2375604138158108"
#      data-ad-slot="7764453390"
#      data-ad-format="auto"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <!--adsense_english_up_end-->
# </div>
# </div>
# <p align="center"><a href="universities-2000.htm" title="More Universities in New Zealand (74 Schools)">More Universities in New Zealand (74 Schools)</a></p>
# <div align="left">
# <div class="list">
# <p>***Universities ***</p>
# <p><a target="_blank" rel="nofollow" href="http://www.aut.ac.nz/">Auckland University of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.Auckland.ac.nz/">The University of Auckland</a>Â </p>
# <p><a target="_blank" rel="nofollow" href="http://www.canterbury.ac.nz">University of canterbury</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.lincoln.ac.nz/">Lincoln University</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.massey.ac.nz/">Massey University</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.otago.ac.nz">University of Otago</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.victoria.ac.nz/">Victoria University of Wellington</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.waikato.ac.nz/">The University or waikato</a></p>
# <p>***Polytechnics and Institutes of Technology***</p>
# <p><a target="_blank" rel="nofollow" href="http://www.ara.ac.nz/">Ara Institute of Canterbury</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.boppoly.ac.nz/">Bay of Plenty Polytechnic</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.cpit.ac.nz/">Christchurch Polytechnic Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.eit.ac.nz/">Eastern Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.laidlaw.ac.nz/">Laidlaw College</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.manukau.ac.nz">Manukau Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="https://www.nmit.ac.nz/">Nelson Marlborough Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.northtec.ac.nz/">NorthTec</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.openpolytechnic.ac.nz/">The Open Polytechnic of New Zealand</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.otagopolytechnic.ac.nz">Otago Polytechnic</a></p>
# <p><a target="_blank" rel="nofollow" href="https://www.sit.ac.nz/">Southern Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.tppweb.ac.nz/">Tai Poutini Polytechnic</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.taranaki.ac.nz/">Taranaki Polytechnic</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.unitec.ac.nz/">UNITEC Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.ucol.ac.nz/">UCOL- Universal College of Learning</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.waiariki.ac.nz/">Waiariki Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.wintec.ac.nz">Waikato Institute of Technology </a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.whanganui.ac.nz/">Wanganui Regional Community Polytechnic</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.cit.ac.nz/">Wellington Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.witt.ac.nz/">Western Institute of Technology</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.whitireia.ac.nz/">Whitireia New Zealand</a></p>
# <p>***Colleges of Education***</p>
# <p><a target="_blank" rel="nofollow" href="http://www.waikato.ac.nz/education">The University of wsikato School of Education</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.wce.ac.nz/">Wellington College of Education</a></p>
# <p>***Private Tertiary Establishments***</p>
# <p><a target="_blank" rel="nofollow" href="http://www.ipc.ac.nz/">International Pacifica College</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.ais.ac.nz/">Auckland Institute of Studies</a></p>
# <p><a target="_blank" rel="nofollow" href="http://www.carey.ac.nz/">Carey Baptist College</a> (Auckland)</p>
# <p><a target="_blank" rel="nofollow" href="http://www.crown.ac.nz/">Crown Institute of Studies</a> (Auckland)</p>
# <p><a target="_blank" rel="nofollow" href="http://www.whitecliffe.ac.nz/">Whitecliffe college of Art and Design</a> (Auckland)</p>
# <p>***<a href="universities-2000.htm" title="More Universities and Colleges in New Zealand (74 Schools)">More Universities  in New Zealand (74 Schools)</a>***</p>
# </div>
# </div>
# <div id="subnav4"><!--down-SubPageNav-start-->
# </div><!--down-SubPageNav-end-->
# <div class="ad-middle">
# <!--adsense_english_down_start-->
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Res-mob-en -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-2375604138158108"
#      data-ad-slot="7764453390"
#      data-ad-format="auto"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <!--adsense_english_down_end-->
# <!-- Content-matched-begin-->
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Content matched -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-2375604138158108"
#      data-ad-slot="2910830192"
#      data-ad-format="autorelaxed"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <!-- Content-matched-end-->
# </div>
#   <div class="list">
# <p align="left"><a href="#top">Back to Top</a></p>
# <p><a href="../index.htm">Back to Home Page</a></p>
#   </div>
# <p>QR CODE OF THIS SITE</p>
# <img src="../Images/QR-CODE02.gif" width="280" height="280">
# <div class="list">
# <p><a href="../us/rank/univ-0000.htm" title="Rankings of Universities inÂ US">Rankings of Universities inÂ US</a></p>
#   <p><a href="../uk/rank/univ-0000.htm" title="Rankings of Universities inÂ US">Rankings of Universities inÂ UK</a></p>
#   <p><a href="../canada/rank-1.htm" title="Rankings of Universities inÂ Canada">Rankings of Universities inÂ Canada</a></p>
#   <p><a href="../New-Zealand/rank-1000.html" title="Rankings of Universities inÂ New Zealand">Rankings of Universities inÂ New Zealand</a></p>
#   <p><a href="../Ireland/rank-1000.html" title="Rankings of Universities inÂ Ireland">Rankings of Universities inÂ Ireland</a></p>
#   <p><a href="../rank/univ-100000.html" title="Rankings of Universities Worldwide">World University Rankings by Subject</a></p>
# </div>
# <!-- InstanceEndEditable --></div>
# <aside>
# <img src="../Images/student.jpg" width="166" height="191">
# <!--adsense_english_right_start-->
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 160x600, åå»ºäº 08-11-5 -->
# <ins class="adsbygoogle"
#      style="display:inline-block;width:160px;height:600px"
#      data-ad-client="ca-pub-2375604138158108"
#      data-ad-slot="7433059211"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <!--adsense_english_right_end-->
# </aside>
# </div>
# <footer>
# <p align="center"><a href="../contact.htm" title="Contact Us">Contact Us </a>&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;<a href="#top" title="Back to Top">Back to Top</a></p>
# <p align="center"><!-- InstanceBeginEditable name="EditRegion8" --><a href="../xinxilan/daxue-1000.htm">Chinese</a><!-- InstanceEndEditable -->&ensp;&ensp;&ensp;&ensp;<!-- InstanceBeginEditable name="EditRegion9" --><a href="https://m.university-list.net/New-Zealand/universities-1000.htm" title="Mobile Version">Mobile</a><!-- InstanceEndEditable -->&nbsp;</p>
# <p align="center"><b>Education Rankings Website</b></p>
#   </footer>
# </div>
# <!--å·¦å¯¼èªjså¼å§-->
# <script src="../js/menu.js" async='async'></script>
# <!--å·¦å¯¼èªjsç»æ-->
# <!-- Googleè·è¸ªä»£ç å¼å§ -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-679909-3', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!-- Googleè·è¸ªä»£ç ç»æ -->
# </body>
# <!-- InstanceEnd --></html>

# %% [markdown]
# Lets look at tidying the data up by parsing the data through **BeautifuleSoup()** and the **prettify()** function to make the data a bit more readable.

# %%
soup = BeautifulSoup(page.text,'html.parser')

# look at the type of object from Beautifule soup
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <!-- InstanceBegin template="/Templates/eng.dwt" codeOutsideHTMLIsLocked="false" -->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="../css/css.css" rel="stylesheet" type="text/css"/>
#   <!--menu.jså¨åºé¨-->
#   <!-- IEè»å­è½¯ä»¶å¼å§ -->
#   <!--â[if lt IE 9]-->
#   <script src="../js/polyfill.js">
#   </script>
#   &lt;![endif]â&gt;
#   <!-- IEè»å­è½¯ä»¶ç»æ -->
#   <!-- auto-adså¼å§ -->
#   <script async="" data-ad-client="ca-pub-2375604138158108" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <!-- auto-adsç»æ -->
#   <!-- InstanceBeginEditable name="doctitle" -->
#   <link href="https://m.university-list.net/New-Zealand/universities-1000.htm" rel="amphtml">
#    <!--å¯¹åºçç§»å¨ç½é¡µ-->
#    <!--<link rel="canonical" href="https://www.university-list.net/New-Zealand/universities-1000.htm" /><!--ææé¦éç½å-->
#    <title>
#     List of Universities and Colleges in New Zealand (36 Schools) - Education Rankings
#    </title>
#    <meta content="List of Universities and Colleges in New Zealand (36 Schools) - Education Rankings. This website provides useful information of studying abroad in main English Countries such as the US, Canada, the UK, Australia, New Zealand and Ireland." name="description"/>
#    <meta content="Universities, Colleges, New Zealand" name="keywords"/>
#    <!-- InstanceEndEditable -->
#    <!-- InstanceBeginEditable name="head" -->
#    <!-- InstanceEndEditable -->
#   </link>
#  </head>
#  <body>
#   <div id="top">
#    <a id="top" name="top">
#    </a>
#    <marquee scrollamount="2">
#     <!-- InstanceBeginEditable name="EditRegion3" -->
#     List of Universities and Colleges in New Zealand (36 Schools)
#     <!-- InstanceEndEditable -->
#    </marquee>
#   </div>
#   <div id="wrapper">
#    <header>
#     <div id="subnav1">
#      <div class="menu" onclick="MM_showHideLayers('left','','show')">
#       Open Menu
#      </div>
#      <div class="version">
#       <!-- InstanceBeginEditable name="EditRegion4" -->
#       <a href="../xinxilan/daxue-1000.htm">
#        Chinese
#        <img align="absmiddle" alt="Chinese Version" border="0" height="23" src="../Images/chin.gif" width="36"/>
#       </a>
#       <!-- InstanceEndEditable -->
#      </div>
#     </div>
#     <div id="banner" role="banner">
#      <!-- InstanceBeginEditable name="EditRegion5" -->
#      List of Universities and Colleges in New Zealand
#      <!-- InstanceEndEditable -->
#     </div>
#     <div id="subnav2">
#      <!-- InstanceBeginEditable name="EditRegion6" -->
#      <a href="../index.htm">
#       Home Page
#      </a>
#      &gt;&gt;
#      <a href="universities-1000.htm" title="Universities in New Zealand">
#       Universities in New Zealand
#      </a>
#      <!-- InstanceEndEditable -->
#     </div>
#    </header>
#    <div id="middle">
#     <div id="left">
#      <div class="closemenu" onclick="MM_showHideLayers('aside','','hide');MM_showHideLayers('left','','hide')">
#       * Close Menu
#       <img height="18" src="../Images/arrow.jpg" width="20"/>
#      </div>
#      <ul>
#       <li>
#        <a href="../index.htm" title="Home Page">
#         <b>
#          Home Page
#         </b>
#        </a>
#       </li>
#       <p>
#        <b>
#         World:
#        </b>
#       </p>
#       <li>
#        <a href="../rank/univ-100000.html" title="Rankings of Universities Worldwide">
#         World University Rankings by Subject
#        </a>
#       </li>
#       <li>
#        <a href="../rank.htm" title="Rankings of Universities Worldwide">
#         Top  Universities Worldwide
#        </a>
#       </li>
#       <p>
#        <strong>
#         <a href="../us/index.html">
#          US:
#         </a>
#        </strong>
#       </p>
#       <li>
#        <a href="../us/universities-0000.htm" title="List of Universities in US">
#         List of Universities in US
#        </a>
#       </li>
#       <li>
#        <a href="../us/rank/univ-0000.htm" title="Rankings of Universities in US">
#         Rankings of Universities in US
#        </a>
#       </li>
#       <li>
#        <a href="../us/language/school-100000.html" title="English Language Schools in US ">
#         Language Schools in US
#        </a>
#       </li>
#       <li>
#        <a href="../us/rank/school-100000.html" title="Rankings of High Schools in US in US ">
#         Rankings of High Schools in US
#        </a>
#       </li>
#       <p>
#        <b>
#         Canada:
#        </b>
#       </p>
#       <li>
#        <a href="../canada/universities-1000.htm" title="List of Universities in Canada">
#         List of Universities in Canada
#        </a>
#       </li>
#       <li>
#        <a href="../canada/rank-1.htm" title="Rankings of Universities in Canada">
#         Rankings of Universities in Canada
#        </a>
#       </li>
#       <li>
#        <a href="../canada/language/school-100000.html" title="English Language Schools in Canada">
#         Language Schools in Canada
#        </a>
#       </li>
#       <p>
#        <b>
#         UK:
#        </b>
#       </p>
#       <li>
#        <a href="../uk/universities-1000.html" title="List of Universities in UK">
#         List of Universities in UK
#        </a>
#       </li>
#       <li>
#        <a href="../uk/rank/univ-0000.htm" title="Rankings of Universities in UK">
#         Rankings of Universities in UK
#        </a>
#       </li>
#       <li>
#        <a href="../uk/language/school-100000.html" title="English Language Schools in the UK ">
#         Language Schools in UK
#        </a>
#       </li>
#       <li>
#        <a href="../uk/rank/school-100000.html" title="Rankings of High Schools in UK ">
#         Rankings of High Schools in UK
#        </a>
#       </li>
#       <p>
#        <b>
#         Australia:
#        </b>
#       </p>
#       <li>
#        <a href="../Australia/universities-1000.htm" title="List of Universities in Australia">
#         List of Universities in Australia
#        </a>
#       </li>
#       <li>
#        <a href="../Australia/rank-1000.html" title="Rankings of Universities in Australia">
#         Rankings of Universities in Australia
#        </a>
#       </li>
#       <li>
#        <a href="../Australia/language/school-100000.html" title="Language Schools in Australia">
#         Language Schools in Australia
#        </a>
#       </li>
#       <li>
#        <a href="../Australia/rank/school-100001.html" title="Rankings of High Schools in Australia ">
#         Rankings of High Schools in Australia
#        </a>
#       </li>
#       <p>
#        <b>
#         New Zealand:
#        </b>
#       </p>
#       <li>
#        <a href="universities-1000.htm" title="List of Universities in New Zealand">
#         List of Universities in New Zealand
#        </a>
#       </li>
#       <li>
#        <a href="rank-1000.html" title="Rankings of Universities in New Zealand">
#         Rankings of Universities in New Zealand
#        </a>
#       </li>
#       <li>
#        <a href="language/school-100000.html" title="Language Schools in New Zealand">
#         Language Schools in New Zealand
#        </a>
#       </li>
#       <p>
#        <b>
#         Ireland:
#        </b>
#       </p>
#       <li>
#        <a href="../Ireland/universities-1000.htm" title="List of Universities in Ireland">
#         List of Universities in Ireland
#        </a>
#       </li>
#       <li>
#        <a href="../Ireland/rank-1000.html" title="Rankings of Universities in Ireland">
#         Rankings of Universities in Ireland
#        </a>
#       </li>
#       <li>
#        <a href="../Ireland/language/school-100000.html" title="Language Schools in Ireland">
#         Language Schools in Ireland
#        </a>
#       </li>
#       <p>
#        <b>
#         Germany:
#        </b>
#       </p>
#       <li>
#        <a href="../germany/rank/univ-000000.html" title="Rankings of Universities in Germany">
#         Rankings of Universities in Germany
#        </a>
#       </li>
#       <p>
#        <b>
#         China:
#        </b>
#       </p>
#       <li>
#        <a href="../china/rank/univ-100001.html" title="Rankings of Universities in China">
#         Rankings of Universities in China
#        </a>
#       </li>
#       <li>
#        <a href="../contact.htm" title="Contact Us">
#         Contact Us
#        </a>
#       </li>
#       <li>
#        <a href="../sitemap.html">
#         Sitemap in English
#        </a>
#       </li>
#      </ul>
#      <div class="closemenu" onclick="MM_showHideLayers('aside','','hide');MM_showHideLayers('left','','hide')">
#       * Close Menu
#       <img height="18" src="../Images/arrow.jpg" width="20"/>
#      </div>
#      <div id="nav-qr-code">
#       <p>
#        QR CODE OF THIS SITE
#       </p>
#       <img height="100" src="../Images/QR-CODE02.gif" width="100"/>
#      </div>
#     </div>
#     <div id="content" role="main">
#      <!--search_english_up_start -->
#      <script>
#       (function() {
#     var cx = '010108428344433716165:olhyzickubi';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = (document.location.protocol == 'https:' ? 'https:' : 'http:') +
#         '//cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#      </script>
#      <gcse:search>
#      </gcse:search>
#      <!--search_english_up_end -->
#      <!-- InstanceBeginEditable name="EditRegion7" -->
#      <h1>
#       <a href="universities-1000.htm" title="List of Universities and Colleges in New Zealand (36 Schools)">
#        List of Universities and Colleges in New Zealand (36 Schools)
#       </a>
#      </h1>
#      <div id="subnav3">
#       <!--up-SubPageNav-start -->
#      </div>
#      <!--up-SubPageNav-end -->
#      <div align="center">
#       <div class="ad-middle">
#        <!--adsense_english_up_start-->
#        <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#        </script>
#        <!-- Res-mob-en -->
#        <ins class="adsbygoogle" data-ad-client="ca-pub-2375604138158108" data-ad-format="auto" data-ad-slot="7764453390" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#        <!--adsense_english_up_end-->
#       </div>
#      </div>
#      <p align="center">
#       <a href="universities-2000.htm" title="More Universities in New Zealand (74 Schools)">
#        More Universities in New Zealand (74 Schools)
#       </a>
#      </p>
#      <div align="left">
#       <div class="list">
#        <p>
#         ***Universities ***
#        </p>
#        <p>
#         <a href="http://www.aut.ac.nz/" rel="nofollow" target="_blank">
#          Auckland University of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.Auckland.ac.nz/" rel="nofollow" target="_blank">
#          The University of Auckland
#         </a>
#         Â
#        </p>
#        <p>
#         <a href="http://www.canterbury.ac.nz" rel="nofollow" target="_blank">
#          University of canterbury
#         </a>
#        </p>
#        <p>
#         <a href="http://www.lincoln.ac.nz/" rel="nofollow" target="_blank">
#          Lincoln University
#         </a>
#        </p>
#        <p>
#         <a href="http://www.massey.ac.nz/" rel="nofollow" target="_blank">
#          Massey University
#         </a>
#        </p>
#        <p>
#         <a href="http://www.otago.ac.nz" rel="nofollow" target="_blank">
#          University of Otago
#         </a>
#        </p>
#        <p>
#         <a href="http://www.victoria.ac.nz/" rel="nofollow" target="_blank">
#          Victoria University of Wellington
#         </a>
#        </p>
#        <p>
#         <a href="http://www.waikato.ac.nz/" rel="nofollow" target="_blank">
#          The University or waikato
#         </a>
#        </p>
#        <p>
#         ***Polytechnics and Institutes of Technology***
#        </p>
#        <p>
#         <a href="http://www.ara.ac.nz/" rel="nofollow" target="_blank">
#          Ara Institute of Canterbury
#         </a>
#        </p>
#        <p>
#         <a href="http://www.boppoly.ac.nz/" rel="nofollow" target="_blank">
#          Bay of Plenty Polytechnic
#         </a>
#        </p>
#        <p>
#         <a href="http://www.cpit.ac.nz/" rel="nofollow" target="_blank">
#          Christchurch Polytechnic Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.eit.ac.nz/" rel="nofollow" target="_blank">
#          Eastern Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.laidlaw.ac.nz/" rel="nofollow" target="_blank">
#          Laidlaw College
#         </a>
#        </p>
#        <p>
#         <a href="http://www.manukau.ac.nz" rel="nofollow" target="_blank">
#          Manukau Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="https://www.nmit.ac.nz/" rel="nofollow" target="_blank">
#          Nelson Marlborough Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.northtec.ac.nz/" rel="nofollow" target="_blank">
#          NorthTec
#         </a>
#        </p>
#        <p>
#         <a href="http://www.openpolytechnic.ac.nz/" rel="nofollow" target="_blank">
#          The Open Polytechnic of New Zealand
#         </a>
#        </p>
#        <p>
#         <a href="http://www.otagopolytechnic.ac.nz" rel="nofollow" target="_blank">
#          Otago Polytechnic
#         </a>
#        </p>
#        <p>
#         <a href="https://www.sit.ac.nz/" rel="nofollow" target="_blank">
#          Southern Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.tppweb.ac.nz/" rel="nofollow" target="_blank">
#          Tai Poutini Polytechnic
#         </a>
#        </p>
#        <p>
#         <a href="http://www.taranaki.ac.nz/" rel="nofollow" target="_blank">
#          Taranaki Polytechnic
#         </a>
#        </p>
#        <p>
#         <a href="http://www.unitec.ac.nz/" rel="nofollow" target="_blank">
#          UNITEC Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.ucol.ac.nz/" rel="nofollow" target="_blank">
#          UCOL- Universal College of Learning
#         </a>
#        </p>
#        <p>
#         <a href="http://www.waiariki.ac.nz/" rel="nofollow" target="_blank">
#          Waiariki Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.wintec.ac.nz" rel="nofollow" target="_blank">
#          Waikato Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.whanganui.ac.nz/" rel="nofollow" target="_blank">
#          Wanganui Regional Community Polytechnic
#         </a>
#        </p>
#        <p>
#         <a href="http://www.cit.ac.nz/" rel="nofollow" target="_blank">
#          Wellington Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.witt.ac.nz/" rel="nofollow" target="_blank">
#          Western Institute of Technology
#         </a>
#        </p>
#        <p>
#         <a href="http://www.whitireia.ac.nz/" rel="nofollow" target="_blank">
#          Whitireia New Zealand
#         </a>
#        </p>
#        <p>
#         ***Colleges of Education***
#        </p>
#        <p>
#         <a href="http://www.waikato.ac.nz/education" rel="nofollow" target="_blank">
#          The University of wsikato School of Education
#         </a>
#        </p>
#        <p>
#         <a href="http://www.wce.ac.nz/" rel="nofollow" target="_blank">
#          Wellington College of Education
#         </a>
#        </p>
#        <p>
#         ***Private Tertiary Establishments***
#        </p>
#        <p>
#         <a href="http://www.ipc.ac.nz/" rel="nofollow" target="_blank">
#          International Pacifica College
#         </a>
#        </p>
#        <p>
#         <a href="http://www.ais.ac.nz/" rel="nofollow" target="_blank">
#          Auckland Institute of Studies
#         </a>
#        </p>
#        <p>
#         <a href="http://www.carey.ac.nz/" rel="nofollow" target="_blank">
#          Carey Baptist College
#         </a>
#         (Auckland)
#        </p>
#        <p>
#         <a href="http://www.crown.ac.nz/" rel="nofollow" target="_blank">
#          Crown Institute of Studies
#         </a>
#         (Auckland)
#        </p>
#        <p>
#         <a href="http://www.whitecliffe.ac.nz/" rel="nofollow" target="_blank">
#          Whitecliffe college of Art and Design
#         </a>
#         (Auckland)
#        </p>
#        <p>
#         ***
#         <a href="universities-2000.htm" title="More Universities and Colleges in New Zealand (74 Schools)">
#          More Universities  in New Zealand (74 Schools)
#         </a>
#         ***
#        </p>
#       </div>
#      </div>
#      <div id="subnav4">
#       <!--down-SubPageNav-start-->
#      </div>
#      <!--down-SubPageNav-end-->
#      <div class="ad-middle">
#       <!--adsense_english_down_start-->
#       <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- Res-mob-en -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-2375604138158108" data-ad-format="auto" data-ad-slot="7764453390" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#       <!--adsense_english_down_end-->
#       <!-- Content-matched-begin-->
#       <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- Content matched -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-2375604138158108" data-ad-format="autorelaxed" data-ad-slot="2910830192" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#       <!-- Content-matched-end-->
#      </div>
#      <div class="list">
#       <p align="left">
#        <a href="#top">
#         Back to Top
#        </a>
#       </p>
#       <p>
#        <a href="../index.htm">
#         Back to Home Page
#        </a>
#       </p>
#      </div>
#      <p>
#       QR CODE OF THIS SITE
#      </p>
#      <img height="280" src="../Images/QR-CODE02.gif" width="280"/>
#      <div class="list">
#       <p>
#        <a href="../us/rank/univ-0000.htm" title="Rankings of Universities inÂ US">
#         Rankings of Universities inÂ US
#        </a>
#       </p>
#       <p>
#        <a href="../uk/rank/univ-0000.htm" title="Rankings of Universities inÂ US">
#         Rankings of Universities inÂ UK
#        </a>
#       </p>
#       <p>
#        <a href="../canada/rank-1.htm" title="Rankings of Universities inÂ Canada">
#         Rankings of Universities inÂ Canada
#        </a>
#       </p>
#       <p>
#        <a href="../New-Zealand/rank-1000.html" title="Rankings of Universities inÂ New Zealand">
#         Rankings of Universities inÂ New Zealand
#        </a>
#       </p>
#       <p>
#        <a href="../Ireland/rank-1000.html" title="Rankings of Universities inÂ Ireland">
#         Rankings of Universities inÂ Ireland
#        </a>
#       </p>
#       <p>
#        <a href="../rank/univ-100000.html" title="Rankings of Universities Worldwide">
#         World University Rankings by Subject
#        </a>
#       </p>
#      </div>
#      <!-- InstanceEndEditable -->
#     </div>
#     <aside>
#      <img height="191" src="../Images/student.jpg" width="166"/>
#      <!--adsense_english_right_start-->
#      <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#      </script>
#      <!-- 160x600, åå»ºäº 08-11-5 -->
#      <ins class="adsbygoogle" data-ad-client="ca-pub-2375604138158108" data-ad-slot="7433059211" style="display:inline-block;width:160px;height:600px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#      <!--adsense_english_right_end-->
#     </aside>
#    </div>
#    <footer>
#     <p align="center">
#      <a href="../contact.htm" title="Contact Us">
#       Contact Us
#      </a>
#      <a href="#top" title="Back to Top">
#       Back to Top
#      </a>
#     </p>
#     <p align="center">
#      <!-- InstanceBeginEditable name="EditRegion8" -->
#      <a href="../xinxilan/daxue-1000.htm">
#       Chinese
#      </a>
#      <!-- InstanceEndEditable -->
#      <!-- InstanceBeginEditable name="EditRegion9" -->
#      <a href="https://m.university-list.net/New-Zealand/universities-1000.htm" title="Mobile Version">
#       Mobile
#      </a>
#      <!-- InstanceEndEditable -->
#     </p>
#     <p align="center">
#      <b>
#       Education Rankings Website
#      </b>
#     </p>
#    </footer>
#   </div>
#   <!--å·¦å¯¼èªjså¼å§-->
#   <script async="async" src="../js/menu.js">
#   </script>
#   <!--å·¦å¯¼èªjsç»æ-->
#   <!-- Googleè·è¸ªä»£ç å¼å§ -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-679909-3', 'auto');
#   ga('send', 'pageview');
#   </script>
#   <!-- Googleè·è¸ªä»£ç ç»æ -->
#  </body>
#  <!-- InstanceEnd -->
# </html>

# %% [markdown]
# As you can see it is much easier to read in a structured format.
#
# Next lets find all ``a`` tags with atributes of ``{'rel':'nofollow'}`` and then display this data.

# %%
all_links = soup.findAll('a',attrs={'rel':'nofollow'})
all_links
# Out:
# [<a href="http://www.aut.ac.nz/" rel="nofollow" target="_blank">Auckland University of Technology</a>,
#  <a href="http://www.Auckland.ac.nz/" rel="nofollow" target="_blank">The University of Auckland</a>,
#  <a href="http://www.canterbury.ac.nz" rel="nofollow" target="_blank">University of canterbury</a>,
#  <a href="http://www.lincoln.ac.nz/" rel="nofollow" target="_blank">Lincoln University</a>,
#  <a href="http://www.massey.ac.nz/" rel="nofollow" target="_blank">Massey University</a>,
#  <a href="http://www.otago.ac.nz" rel="nofollow" target="_blank">University of Otago</a>,
#  <a href="http://www.victoria.ac.nz/" rel="nofollow" target="_blank">Victoria University of Wellington</a>,
#  <a href="http://www.waikato.ac.nz/" rel="nofollow" target="_blank">The University or waikato</a>,
#  <a href="http://www.ara.ac.nz/" rel="nofollow" target="_blank">Ara Institute of Canterbury</a>,
#  <a href="http://www.boppoly.ac.nz/" rel="nofollow" target="_blank">Bay of Plenty Polytechnic</a>,
#  <a href="http://www.cpit.ac.nz/" rel="nofollow" target="_blank">Christchurch Polytechnic Institute of Technology</a>,
#  <a href="http://www.eit.ac.nz/" rel="nofollow" target="_blank">Eastern Institute of Technology</a>,
#  <a href="http://www.laidlaw.ac.nz/" rel="nofollow" target="_blank">Laidlaw College</a>,
#  <a href="http://www.manukau.ac.nz" rel="nofollow" target="_blank">Manukau Institute of Technology</a>,
#  <a href="https://www.nmit.ac.nz/" rel="nofollow" target="_blank">Nelson Marlborough Institute of Technology</a>,
#  <a href="http://www.northtec.ac.nz/" rel="nofollow" target="_blank">NorthTec</a>,
#  <a href="http://www.openpolytechnic.ac.nz/" rel="nofollow" target="_blank">The Open Polytechnic of New Zealand</a>,
#  <a href="http://www.otagopolytechnic.ac.nz" rel="nofollow" target="_blank">Otago Polytechnic</a>,
#  <a href="https://www.sit.ac.nz/" rel="nofollow" target="_blank">Southern Institute of Technology</a>,
#  <a href="http://www.tppweb.ac.nz/" rel="nofollow" target="_blank">Tai Poutini Polytechnic</a>,
#  <a href="http://www.taranaki.ac.nz/" rel="nofollow" target="_blank">Taranaki Polytechnic</a>,
#  <a href="http://www.unitec.ac.nz/" rel="nofollow" target="_blank">UNITEC Institute of Technology</a>,
#  <a href="http://www.ucol.ac.nz/" rel="nofollow" target="_blank">UCOL- Universal College of Learning</a>,
#  <a href="http://www.waiariki.ac.nz/" rel="nofollow" target="_blank">Waiariki Institute of Technology</a>,
#  <a href="http://www.wintec.ac.nz" rel="nofollow" target="_blank">Waikato Institute of Technology </a>,
#  <a href="http://www.whanganui.ac.nz/" rel="nofollow" target="_blank">Wanganui Regional Community Polytechnic</a>,
#  <a href="http://www.cit.ac.nz/" rel="nofollow" target="_blank">Wellington Institute of Technology</a>,
#  <a href="http://www.witt.ac.nz/" rel="nofollow" target="_blank">Western Institute of Technology</a>,
#  <a href="http://www.whitireia.ac.nz/" rel="nofollow" target="_blank">Whitireia New Zealand</a>,
#  <a href="http://www.waikato.ac.nz/education" rel="nofollow" target="_blank">The University of wsikato School of Education</a>,
#  <a href="http://www.wce.ac.nz/" rel="nofollow" target="_blank">Wellington College of Education</a>,
#  <a href="http://www.ipc.ac.nz/" rel="nofollow" target="_blank">International Pacifica College</a>,
#  <a href="http://www.ais.ac.nz/" rel="nofollow" target="_blank">Auckland Institute of Studies</a>,
#  <a href="http://www.carey.ac.nz/" rel="nofollow" target="_blank">Carey Baptist College</a>,
#  <a href="http://www.crown.ac.nz/" rel="nofollow" target="_blank">Crown Institute of Studies</a>,
#  <a href="http://www.whitecliffe.ac.nz/" rel="nofollow" target="_blank">Whitecliffe college of Art and Design</a>]

# %% [markdown]
# Next we will use a loop to provide us with only the URL and university names.

# %%
for eachuniversity in all_links: 
    print(eachuniversity['href']+" ,"+eachuniversity.string)
# Out:
# http://www.aut.ac.nz/ ,Auckland University of Technology
# http://www.Auckland.ac.nz/ ,The University of Auckland
# http://www.canterbury.ac.nz ,University of canterbury
# http://www.lincoln.ac.nz/ ,Lincoln University
# http://www.massey.ac.nz/ ,Massey University
# http://www.otago.ac.nz ,University of Otago
# http://www.victoria.ac.nz/ ,Victoria University of Wellington
# http://www.waikato.ac.nz/ ,The University or waikato
# http://www.ara.ac.nz/ ,Ara Institute of Canterbury
# http://www.boppoly.ac.nz/ ,Bay of Plenty Polytechnic
# http://www.cpit.ac.nz/ ,Christchurch Polytechnic Institute of Technology
# http://www.eit.ac.nz/ ,Eastern Institute of Technology
# http://www.laidlaw.ac.nz/ ,Laidlaw College
# http://www.manukau.ac.nz ,Manukau Institute of Technology
# https://www.nmit.ac.nz/ ,Nelson Marlborough Institute of Technology
# http://www.northtec.ac.nz/ ,NorthTec
# http://www.openpolytechnic.ac.nz/ ,The Open Polytechnic of New Zealand
# http://www.otagopolytechnic.ac.nz ,Otago Polytechnic
# https://www.sit.ac.nz/ ,Southern Institute of Technology
# http://www.tppweb.ac.nz/ ,Tai Poutini Polytechnic
# http://www.taranaki.ac.nz/ ,Taranaki Polytechnic
# http://www.unitec.ac.nz/ ,UNITEC Institute of Technology
# http://www.ucol.ac.nz/ ,UCOL- Universal College of Learning
# http://www.waiariki.ac.nz/ ,Waiariki Institute of Technology
# http://www.wintec.ac.nz ,Waikato Institute of Technology
# http://www.whanganui.ac.nz/ ,Wanganui Regional Community Polytechnic
# http://www.cit.ac.nz/ ,Wellington Institute of Technology
# http://www.witt.ac.nz/ ,Western Institute of Technology
# http://www.whitireia.ac.nz/ ,Whitireia New Zealand
# http://www.waikato.ac.nz/education ,The University of wsikato School of Education
# http://www.wce.ac.nz/ ,Wellington College of Education
# http://www.ipc.ac.nz/ ,International Pacifica College
# http://www.ais.ac.nz/ ,Auckland Institute of Studies
# http://www.carey.ac.nz/ ,Carey Baptist College
# http://www.crown.ac.nz/ ,Crown Institute of Studies
# http://www.whitecliffe.ac.nz/ ,Whitecliffe college of Art and Design

# %% [markdown]
# ### Activity Web Scraping
#
# In this activity we will scrape the Wikipedia page for the following URL:
#
# ``"https://en.wikipedia.org/wiki/States_of_Germany"``
#
# The final goal of this activity is to get a listing of German States.
#
# First we will import our libraries and pull and parse our data and display our title page.

# %%
#import the library used to query a website
import requests

# import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup
import time


#specify the url

wiki = "https://en.wikipedia.org/wiki/States_of_Germany"

#Query the website and return the html to the variable 'page'
page = requests.get(wiki)

# Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(page.text,'html.parser')

# Goal 1
print(soup.title.string)
# Out:
# States of Germany - Wikipedia

# %% [markdown]
# Next we will use the``findAll()`` function to search for all ``'a'`` tags. We will then print out all links with ``['href']``.

# %%
# Goal 2

all_links = soup.findAll('a',href=True)

# print all links from the webpage
for link in all_links:
    print(link['href'])
# Out:
# #mw-head
# #searchInput
# /wiki/States_of_Germany_(disambiguation)
# /wiki/Regions_of_Germany_(disambiguation)
# https://en.wikipedia.org/w/index.php?title=States_of_Germany&action=edit
# /wiki/Talk:States_of_Germany
# /wiki/Help:Maintenance_template_removal
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Verifiability
# https://en.wikipedia.org/w/index.php?title=States_of_Germany&action=edit
# /wiki/Help:Referencing_for_beginners
# //www.google.com/search?as_eq=wikipedia&q=%22States+of+Germany%22
# //www.google.com/search?tbm=nws&q=%22States+of+Germany%22+-wikipedia
# //www.google.com/search?&q=%22States+of+Germany%22+site:news.google.com/newspapers&source=newspapers
# //www.google.com/search?tbs=bks:1&q=%22States+of+Germany%22+-wikipedia
# //scholar.google.com/scholar?q=%22States+of+Germany%22
# https://www.jstor.org/action/doBasicSearch?Query=%22States+of+Germany%22&acc=on&wc=on
# /wiki/Help:Maintenance_template_removal
# /wiki/Wikipedia:Manual_of_Style/Layout
# https://en.wikipedia.org/w/index.php?title=States_of_Germany&action=edit
# /wiki/Help:Maintenance_template_removal
# /wiki/Help:Maintenance_template_removal
# /wiki/German_language
# /wiki/Federated_countries
# /wiki/Lower_Saxony
# /wiki/Lower_Saxony
# /wiki/Free_Hanseatic_City_of_Bremen
# /wiki/Bremen_(state)
# /wiki/Hamburg
# /wiki/Hamburg
# /wiki/Mecklenburg-Vorpommern
# /wiki/Mecklenburg-Vorpommern
# /wiki/Saxony-Anhalt
# /wiki/Saxony-Anhalt
# /wiki/Saxony
# /wiki/Saxony
# /wiki/Brandenburg
# /wiki/Brandenburg
# /wiki/Berlin
# /wiki/Berlin
# /wiki/Thuringia
# /wiki/Thuringia
# /wiki/Hesse
# /wiki/Hesse
# /wiki/North_Rhine-Westphalia
# /wiki/North_Rhine-Westphalia
# /wiki/Rhineland-Palatinate
# /wiki/Rhineland-Palatinate
# /wiki/Bavaria
# /wiki/Bavaria
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Saarland
# /wiki/Saarland
# /wiki/Schleswig-Holstein
# /wiki/Schleswig-Holstein
# /wiki/Federated_state
# /wiki/Federal_Republic_of_Germany
# /wiki/Bremen_(state)
# /wiki/North_Rhine-Westphalia
# /wiki/Bremen_(state)
# /wiki/Bavaria
# /wiki/State_government
# /wiki/Borough
# /wiki/Districts_of_Germany
# /wiki/Amt_(country_subdivision)
# /wiki/Regierungsbezirk
# /wiki/Germany
# /wiki/File:Coat_of_arms_of_Germany.svg
# /wiki/Politics_of_Germany
# /wiki/Basic_Law_for_the_Federal_Republic_of_Germany
# /wiki/Federal_Constitutional_Court_of_Germany
# /wiki/Human_rights_in_Germany
# /wiki/President_of_Germany
# /wiki/Frank-Walter_Steinmeier
# /wiki/Federal_Convention_(Germany)
# /wiki/Chancellor_of_Germany_(1949%E2%80%93)
# /wiki/List_of_Chancellors_of_Germany#Federal_Republic
# /wiki/Angela_Merkel
# /wiki/Vice-Chancellor_of_Germany
# /wiki/Olaf_Scholz
# /wiki/Cabinet_of_Germany
# /wiki/Fourth_Merkel_cabinet
# /wiki/Bundesrat_of_Germany
# /wiki/Bundestag
# /wiki/Gemeinsamer_Ausschuss
# /wiki/Judiciary_of_Germany
# /wiki/Federal_Constitutional_Court
# /wiki/Federal_Administrative_Court_(Germany)
# /wiki/Federal_Court_of_Justice
# /wiki/Federal_Fiscal_Court
# /wiki/Federal_Labour_Court
# /wiki/Federal_Social_Court
# /wiki/Administrative_divisions_of_Germany
# /wiki/Minister_president_(Germany)
# /wiki/State_Parliament_(Germany)
# /wiki/Regierungsbezirk
# /wiki/Districts_of_Germany
# /wiki/Amt_(country_subdivision)
# /wiki/Municipalities_of_Germany
# /wiki/Elections_in_Germany
# /wiki/Electoral_system_of_Germany
# /wiki/List_of_political_parties_in_Germany
# /wiki/Referendums_in_Germany
# /wiki/Foreign_relations_of_Germany
# /wiki/Germany-France_relations
# /wiki/Germany-Italy_relations
# /wiki/Germany-United_Kingdom_relations
# /wiki/Germany-United_States_relations
# /wiki/Germany-Russia_relations
# /wiki/Politics_of_the_European_Union
# /wiki/Outline_of_political_science#Politics_by_region
# /wiki/Template:Politics_of_Germany
# /wiki/Template_talk:Politics_of_Germany
# https://en.wikipedia.org/w/index.php?title=Template:Politics_of_Germany&action=edit
# /wiki/Federal_Republic_of_Germany
# /wiki/Federal_state
# /wiki/Federated_states
# /wiki/German_language
# #cite_note-3
# /wiki/Germany
# /wiki/Constituent_states
# /wiki/Berlin
# /wiki/Hamburg
# /wiki/City-state
# /wiki/Bremen_(state)
# /wiki/Bremen
# /wiki/Bremerhaven
# /wiki/West_Germany
# /wiki/World_War_II
# /wiki/South_Baden
# /wiki/Bavaria
# /wiki/Bremen_(state)
# /wiki/Hamburg
# /wiki/Hesse
# /wiki/Lower_Saxony
# /wiki/North_Rhine-Westphalia
# /wiki/Rhineland-Palatinate
# /wiki/Schleswig-Holstein
# /wiki/W%C3%BCrttemberg-Baden
# /wiki/W%C3%BCrttemberg-Hohenzollern
# /wiki/West_Berlin
# /wiki/De_facto
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Saar_Protectorate
# /wiki/Saarland
# /wiki/German_reunification
# /wiki/East_Germany
# /wiki/New_states_of_Germany
# /wiki/Brandenburg
# /wiki/Mecklenburg-Vorpommern
# /wiki/Saxony
# /wiki/Saxony-Anhalt
# /wiki/Thuringia
# /wiki/West_Berlin
# /wiki/East_Berlin
# /wiki/Berlin
# /wiki/Federalism_in_Germany
# /wiki/German_constitution
# /wiki/Bundesrat_of_Germany
# #cite_note-4
# #States
# #List
# #History
# #West_Germany,_1945–90
# #Establishment_of_Baden-Württemberg
# #Petitions_to_reconstitute_former_states
# #Saar:_the_little_reunification
# #Constitutional_amendments
# #Reunited_Germany,_1990–present
# #Politics
# #Government
# #Subdivisions
# #Area_associations_(Landschaftsverbände)
# #Governmental_districts_(Regierungsbezirke)
# #Administrative_districts_(Kreise)
# #Offices_(Ämter)
# #Municipalities_(Gemeinden)
# #See_also
# #Notes
# #References
# #External_links
# /w/index.php?title=States_of_Germany&action=edit&section=1
# /wiki/Austria
# /wiki/Weimar_Constitution
# /wiki/German_Empire
# /wiki/Freistaat
# /wiki/Weimar_Republic
# /wiki/Bavaria
# /wiki/Bremen
# /wiki/Hamburg
# /wiki/Hesse
# /wiki/Saxony
# /wiki/Thuringia
# /wiki/Anhalt
# /wiki/Saxony-Anhalt
# /wiki/South_Baden
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Braunschweig_(state)
# /wiki/Lower_Saxony
# /wiki/Free_State_of_Lippe
# /wiki/North_Rhine-Westphalia
# /wiki/L%C3%BCbeck
# /wiki/Schleswig-Holstein
# /wiki/Mecklenburg-Schwerin
# /wiki/Mecklenburg-Vorpommern
# /wiki/Mecklenburg-Strelitz
# /wiki/Mecklenburg-Vorpommern
# /wiki/Oldenburg_(state)
# /wiki/Lower_Saxony
# /wiki/Rhineland-Palatinate
# /wiki/Schleswig-Holstein
# /wiki/Prussia
# /wiki/Berlin
# /wiki/Brandenburg
# /wiki/Lower_Saxony
# /wiki/North_Rhine-Westphalia
# /wiki/Rhineland-Palatinate
# /wiki/Saxony-Anhalt
# /wiki/Schleswig-Holstein
# /wiki/Bavaria
# /wiki/Neisse
# /wiki/Oder
# /wiki/Poland
# /wiki/Russia
# /wiki/Schaumburg-Lippe
# /wiki/Lower_Saxony
# /wiki/W%C3%BCrttemberg
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Boundary_delimitation
# #cite_note-5
# #cite_note-6
# #cite_note-7
# /w/index.php?title=States_of_Germany&action=edit&section=2
# /wiki/Coats_of_arms_of_German_states
# /wiki/Flags_of_German_states
# /wiki/Bundesrat_of_Germany
# #cite_note-8
# /wiki/Human_Development_Index
# #cite_note-9
# /wiki/ISO_3166-2:DE
# /wiki/GDP
# /wiki/Euro
# #cite_note-10
# /wiki/Coat_of_arms_of_Baden-W%C3%BCrttemberg
# /wiki/Flag_of_Baden-W%C3%BCrttemberg
# /wiki/Baden-W%C3%BCrttemberg
# #cite_note-11
# /wiki/Stuttgart
# /wiki/Landtag_of_Baden-W%C3%BCrttemberg
# /wiki/Winfried_Kretschmann
# /wiki/Alliance_%2790/The_Greens
# /wiki/Christian_Democratic_Union_(Germany)
# /wiki/Coat_of_arms_of_Bavaria
# /wiki/Flag_of_Bavaria
# /wiki/Bavaria
# /wiki/Munich
# /wiki/Landtag_of_Bavaria
# /wiki/Markus_S%C3%B6der
# /wiki/Christian_Social_Union_of_Bavaria
# /wiki/Free_Voters_of_Bavaria
# /wiki/Coat_of_arms_of_Berlin
# /wiki/Flag_of_Berlin
# /wiki/Berlin
# #cite_note-12
# /wiki/Abgeordnetenhaus_of_Berlin
# /wiki/Michael_M%C3%BCller_(politician,_born_1964)
# /wiki/SPD
# /wiki/The_Left_(Germany)
# /wiki/Alliance_%2790/The_Greens
# /wiki/Coat_of_arms_of_Brandenburg
# /wiki/Flag_of_Brandenburg
# /wiki/Brandenburg
# /wiki/Potsdam
# /wiki/Landtag_of_Brandenburg
# /wiki/Dietmar_Woidke
# /wiki/Coat_of_arms_of_Bremen
# /wiki/Flag_of_Bremen_(state)
# /wiki/Bremen_(state)
# /wiki/Bremen
# /wiki/B%C3%BCrgerschaft_of_Bremen
# /wiki/Andreas_Bovenschulte
# /wiki/Coat_of_arms_of_Hamburg
# /wiki/Flag_of_Hamburg
# /wiki/Hamburg
# /wiki/Hamburg_Parliament
# /wiki/Peter_Tschentscher
# /wiki/Coat_of_arms_of_Hesse
# /wiki/Flag_of_Hesse
# /wiki/Hesse
# /wiki/Wiesbaden
# /wiki/Landtag_of_Hesse
# /wiki/Volker_Bouffier
# /wiki/Coat_of_arms_of_Lower_Saxony
# /wiki/Flag_of_Lower_Saxony
# /wiki/Lower_Saxony
# /wiki/Hanover
# /wiki/Landtag_of_Lower_Saxony
# /wiki/Stephan_Weil
# /wiki/Coat_of_arms_of_Mecklenburg-Vorpommern
# /wiki/Flag_of_Mecklenburg-Vorpommern
# /wiki/Mecklenburg-Vorpommern
# /wiki/Schwerin
# /wiki/Landtag_of_Mecklenburg-Vorpommern
# /wiki/Manuela_Schwesig
# /wiki/Coat_of_arms_of_North_Rhine-Westphalia
# /wiki/Flag_of_North_Rhine-Westphalia
# /wiki/North_Rhine-Westphalia
# /wiki/D%C3%BCsseldorf
# /wiki/Landtag_of_North_Rhine-Westphalia
# /wiki/Armin_Laschet
# /wiki/Coat_of_arms_of_Rhineland-Palatinate
# /wiki/Flag_of_Rhineland-Palatinate
# /wiki/Rhineland-Palatinate
# /wiki/Mainz
# /wiki/Landtag_of_Rhineland-Palatinate
# /wiki/Malu_Dreyer
# /wiki/Free_Democratic_Party_(Germany)
# /wiki/Coat_of_arms_of_Saarland
# /wiki/Flag_of_Saarland
# /wiki/Saarland
# /wiki/Saarbr%C3%BCcken
# /wiki/Landtag_of_Saarland
# /wiki/Tobias_Hans
# /wiki/Coat_of_arms_of_Saxony
# /wiki/Flag_of_Saxony
# /wiki/Saxony
# /wiki/Dresden
# /wiki/Landtag_of_Saxony
# /wiki/Michael_Kretschmer
# /wiki/Coat_of_arms_of_Saxony-Anhalt
# /wiki/Flag_of_Saxony-Anhalt
# /wiki/Saxony-Anhalt
# /wiki/Magdeburg
# /wiki/Landtag_of_Saxony-Anhalt
# /wiki/Reiner_Haseloff
# /wiki/Coat_of_arms_of_Schleswig-Holstein
# /wiki/Flag_of_Schleswig-Holstein
# /wiki/Schleswig-Holstein
# /wiki/Kiel
# /wiki/Landtag_of_Schleswig-Holstein
# /wiki/Daniel_G%C3%BCnther
# /wiki/Coat_of_arms_of_Thuringia
# /wiki/Flag_of_Thuringia
# /wiki/Thuringia
# /wiki/Erfurt
# /wiki/Landtag_of_Thuringia
# /wiki/Bodo_Ramelow
# /w/index.php?title=States_of_Germany&action=edit&section=3
# /wiki/List_of_historic_states_of_Germany
# /wiki/History_of_Germany
# /wiki/Federalism
# /wiki/Holy_Roman_Empire
# /wiki/Kleinstaaterei
# /wiki/Napoleonic_Wars
# /wiki/Congress_of_Vienna
# /wiki/German_Confederation
# /wiki/Austro-Prussian_War
# /wiki/Kingdom_of_Prussia
# /wiki/Federal_state
# /wiki/North_German_Federation
# /wiki/Franco-Prussian_War
# /wiki/German_Empire
# /wiki/German_Empire
# /wiki/Hanseatic_League
# /wiki/Alsace-Lorraine
# /wiki/Treaty_of_Versailles
# /wiki/Administrative_divisions_of_Weimar_Germany
# /wiki/Gleichschaltung
# /wiki/Administrative_divisions_of_Nazi_Germany
# /wiki/File:German_Empire_states_map.svg
# /wiki/File:German_Empire_states_map.svg
# /wiki/Kingdom_of_Prussia
# /wiki/German_Empire
# /wiki/Allied_Occupation_Zones_in_Germany
# /wiki/Oder-Neisse_line
# /wiki/Provinces_of_Prussia
# /wiki/Farther_Pomerania
# /wiki/East_Prussia
# /wiki/Silesia
# /wiki/Posen-West_Prussia
# #cite_note-13
# /wiki/Flight_and_expulsion_of_Germans_from_Poland_during_and_after_World_War_II
# /wiki/West_Germany
# /wiki/South_Baden
# /wiki/W%C3%BCrttemberg-Hohenzollern
# /wiki/W%C3%BCrttemberg-Baden
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Saar_Protectorate
# /wiki/Saarland
# /wiki/Old_states_of_Germany
# /wiki/East_Germany
# /wiki/Administrative_division_of_the_German_Democratic_Republic
# /wiki/German_reunification
# /wiki/New_states_of_Germany
# /wiki/File:Weimar_Republic_states_map.svg
# /wiki/File:Weimar_Republic_states_map.svg
# /wiki/States_of_the_Weimar_Republic
# /wiki/Free_State_of_Prussia
# /wiki/Grundgesetz
# /wiki/Saar_Protectorate
# /wiki/Saarland
# /wiki/Free_state_(government)
# /wiki/Bundesrat_(Germany)
# /w/index.php?title=States_of_Germany&action=edit&section=4
# /wiki/Basic_Law_for_the_Federal_Republic_of_Germany
# /w/index.php?title=Werner_Rutz&action=edit&redlink=1
# /wiki/Meinhard_Miegel
# /w/index.php?title=Adrian_Ottnad&action=edit&redlink=1
# /w/index.php?title=Walter_D%C3%B6ring&action=edit&redlink=1
# /wiki/Hans_Apel
# /wiki/Equalization_payments
# /wiki/Germany
# /wiki/Holy_Roman_Empire
# /wiki/Confederation
# /wiki/Suzerainty
# /wiki/Holy_Roman_Emperor
# /wiki/French_Revolution
# /wiki/Napoleonic_Wars
# /wiki/Congress_of_Vienna
# /wiki/Prussia
# /wiki/Kingdom_of_Hanover
# /wiki/Nassau_(state)
# /wiki/Electorate_of_Hesse
# /wiki/Free_City_of_Frankfurt
# /wiki/Allied-occupied_Germany
# /wiki/Hugo_Preuss
# /wiki/Weimar_Constitution
# /wiki/German_Reich
# /wiki/Thuringia
# /wiki/Saxe-Coburg
# /wiki/Bavaria
# /wiki/Waldeck_(state)
# /wiki/Nazi_Party
# /wiki/Free_State_of_Mecklenburg-Schwerin
# /wiki/Free_State_of_Mecklenburg-Strelitz
# /wiki/Greater_Hamburg_Act
# /wiki/Free_City_of_L%C3%BCbeck
# /wiki/Province_of_Schleswig-Holstein
# /wiki/File:Deutschland_Bundeslaender_1957.png
# /wiki/File:Deutschland_Bundeslaender_1957.png
# /wiki/West_Germany
# /wiki/East_Germany
# /wiki/West_Berlin
# /wiki/Bremen_(state)
# /wiki/Hesse
# /wiki/W%C3%BCrttemberg-Baden
# /wiki/Bavaria
# /wiki/Hamburg
# /wiki/Schleswig-Holstein
# /wiki/Lower_Saxony
# /wiki/North_Rhine-Westphalia
# /wiki/Rhineland-Palatinate
# /wiki/South_Baden
# /wiki/W%C3%BCrttemberg-Hohenzollern
# /wiki/Saarland
# /wiki/Mecklenburg-Vorpommern
# /wiki/Brandenburg
# /wiki/Saxony
# /wiki/Saxony-Anhalt
# /wiki/Thuringia
# /wiki/Frankfurt_Documents
# /wiki/Parlamentarischer_Rat
# /wiki/Konrad_Adenauer
# /w/index.php?title=States_of_Germany&action=edit&section=5
# /wiki/A8_motorway_(Germany)
# /wiki/Baden
# /wiki/W%C3%BCrttemberg-Baden
# /w/index.php?title=W%C3%BCrttemberg-Hohenzoller&action=edit&redlink=1
# /wiki/Referendum
# /wiki/South_Baden
# /w/index.php?title=States_of_Germany&action=edit&section=6
# /wiki/London_and_Paris_Conferences
# /wiki/Free_State_of_Oldenburg
# /wiki/Free_State_of_Schaumburg-Lippe
# /wiki/Koblenz_(region)
# /wiki/Trier_(region)
# /wiki/North_Rhine-Westphalia
# /wiki/Rheinhessen_(region)
# /wiki/Hesse
# /wiki/Montabaur_(region)
# /wiki/Republic_of_Baden
# /wiki/Federal_Constitutional_Court_of_Germany
# /wiki/Pfalz_(region)
# /w/index.php?title=States_of_Germany&action=edit&section=7
# /wiki/Saar_Protectorate
# /wiki/Paris_Agreements
# /wiki/Western_European_Union
# /wiki/Saar_Statute_referendum,_1955
# /wiki/Konrad_Adenauer
# #cite_note-14
# /wiki/Saar_Treaty
# /wiki/Grundgesetz
# /wiki/Deutsche_Mark
# /w/index.php?title=States_of_Germany&action=edit&section=8
# /wiki/Grand_coalition_(Germany)
# /wiki/Willy_Brandt
# /wiki/Cuxhaven
# /wiki/L%C3%BCchow-Dannenberg
# /wiki/Germersheim_(district)
# /wiki/Rhine-Neckar
# /wiki/Worms,_Germany
# /wiki/Republic_of_Baden
# #cite_note-15
# /w/index.php?title=States_of_Germany&action=edit&section=9
# /wiki/German_reunification
# /wiki/New_states_of_Germany
# /w/index.php?title=States_of_Germany&action=edit&section=10
# /wiki/Germany
# /wiki/File:Coat_of_arms_of_Germany.svg
# /wiki/Politics_of_Germany
# /wiki/Basic_Law_for_the_Federal_Republic_of_Germany
# /wiki/Federal_Constitutional_Court_of_Germany
# /wiki/Human_rights_in_Germany
# /wiki/President_of_Germany
# /wiki/Frank-Walter_Steinmeier
# /wiki/Federal_Convention_(Germany)
# /wiki/Chancellor_of_Germany_(1949%E2%80%93)
# /wiki/List_of_Chancellors_of_Germany#Federal_Republic
# /wiki/Angela_Merkel
# /wiki/Vice-Chancellor_of_Germany
# /wiki/Olaf_Scholz
# /wiki/Cabinet_of_Germany
# /wiki/Fourth_Merkel_cabinet
# /wiki/Bundesrat_of_Germany
# /wiki/Bundestag
# /wiki/Gemeinsamer_Ausschuss
# /wiki/Judiciary_of_Germany
# /wiki/Federal_Constitutional_Court
# /wiki/Federal_Administrative_Court_(Germany)
# /wiki/Federal_Court_of_Justice
# /wiki/Federal_Fiscal_Court
# /wiki/Federal_Labour_Court
# /wiki/Federal_Social_Court
# /wiki/Administrative_divisions_of_Germany
# /wiki/Minister_president_(Germany)
# /wiki/State_Parliament_(Germany)
# /wiki/Regierungsbezirk
# /wiki/Districts_of_Germany
# /wiki/Amt_(country_subdivision)
# /wiki/Municipalities_of_Germany
# /wiki/Elections_in_Germany
# /wiki/Electoral_system_of_Germany
# /wiki/List_of_political_parties_in_Germany
# /wiki/Referendums_in_Germany
# /wiki/Foreign_relations_of_Germany
# /wiki/Germany-France_relations
# /wiki/Germany-Italy_relations
# /wiki/Germany-United_Kingdom_relations
# /wiki/Germany-United_States_relations
# /wiki/Germany-Russia_relations
# /wiki/Politics_of_the_European_Union
# /wiki/Outline_of_political_science#Politics_by_region
# /wiki/Template:Politics_of_Germany
# /wiki/Template_talk:Politics_of_Germany
# https://en.wikipedia.org/w/index.php?title=Template:Politics_of_Germany&action=edit
# /wiki/Federalism_in_Germany
# /w/index.php?title=States_of_Germany&action=edit&section=11
# /wiki/Basic_Law_of_the_Federal_Republic_of_Germany
# /wiki/Federation
# /wiki/Constitution
# /wiki/Cabinet_(government)
# /wiki/Minister_president_(Germany)
# /wiki/Unicameral
# /wiki/Legislature
# /wiki/Landtag
# /wiki/Diet_(assembly)
# /wiki/Parliamentary_republic
# /wiki/Majority_vote
# /wiki/No-confidence_vote
# /wiki/Berlin
# /wiki/Bremen_(state)
# /wiki/Hamburg
# /wiki/Senate#Alternative_meanings
# /wiki/Free_state_(government)
# /wiki/Bavaria
# /wiki/Free_State_of_Saxony
# /wiki/Thuringia
# /wiki/Bicameral
# /wiki/Landtag_of_Bavaria
# /wiki/Senate
# /wiki/Referendum
# /w/index.php?title=States_of_Germany&action=edit&section=12
# /wiki/File:Administrative_divisions_of_Germany.svg
# /wiki/File:Administrative_divisions_of_Germany.svg
# /wiki/City-state
# /wiki/Borough
# /wiki/List_of_German_urban_districts
# /wiki/Bremen
# /wiki/Bremerhaven
# /w/index.php?title=States_of_Germany&action=edit&section=13
# /wiki/Landschaftsverband
# /wiki/Rhineland
# /wiki/Westphalia
# /wiki/Lippe
# /wiki/World_War_II
# /wiki/Mecklenburg-Vorpommern
# /wiki/Mecklenburg
# /wiki/Vorpommern
# /w/index.php?title=States_of_Germany&action=edit&section=14
# /wiki/Regierungsbezirk
# /w/index.php?title=Landesdirektion_Sachsen&action=edit&redlink=1
# https://de.wikipedia.org/wiki/Landesdirektion_Sachsen
# /w/index.php?title=States_of_Germany&action=edit&section=15
# /wiki/Districts_of_Germany
# /wiki/List_of_districts_of_Germany
# /wiki/File:Landkreise,_Kreise_und_kreisfreie_St%C3%A4dte_in_Deutschland_2011-09-04.svg
# /wiki/File:Landkreise,_Kreise_und_kreisfreie_St%C3%A4dte_in_Deutschland_2011-09-04.svg
# /wiki/Districts_of_Germany
# /wiki/Berlin
# /wiki/Hamburg
# /wiki/Bremen_(state)
# /wiki/Bremen_(state)
# /wiki/County_executive
# /wiki/United_States_of_America
# /wiki/Hinterland
# /wiki/Hanover_(district)
# /wiki/Hanover
# /wiki/Saarbr%C3%BCcken_(district)
# /wiki/Saarbr%C3%BCcken
# /wiki/Aachen_(district)
# /wiki/Aachen
# /w/index.php?title=States_of_Germany&action=edit&section=16
# /wiki/Amt_(country_subdivision)
# /w/index.php?title=States_of_Germany&action=edit&section=17
# /wiki/Municipality
# https://en.wikipedia.org/w/index.php?title=States_of_Germany&action=edit
# /wiki/Stadtrecht
# /wiki/Berlin
# /wiki/Gr%C3%B6de
# /wiki/Nordfriesland
# /wiki/Trading_estate
# /wiki/Arts_centres
# /wiki/Unincorporated_area
# /wiki/Bavaria
# /wiki/Lower_Saxony
# /wiki/Hesse
# /wiki/Schleswig-Holstein
# /wiki/Baden-W%C3%BCrttemberg
# /w/index.php?title=States_of_Germany&action=edit&section=18
# /wiki/Portal:Germany
# /wiki/Portal:Europe
# /wiki/Portal:European_Union
# /wiki/Portal:Geography
# /wiki/Cantons_of_Switzerland
# /wiki/Composition_of_the_German_State_Parliaments
# /wiki/Elections_in_Germany
# /wiki/2_euro_commemorative_coins#German_Bundesländer_series
# /wiki/Landespolizei
# /wiki/List_of_cities_in_Germany
# /wiki/List_of_German_states_by_area
# /wiki/List_of_German_states_by_exports
# /wiki/List_of_German_states_by_fertility_rate
# /wiki/List_of_German_states_by_GDP
# /wiki/List_of_German_states_by_household_income
# /wiki/List_of_German_states_by_Human_Development_Index
# /wiki/List_of_German_states_by_life_expectancy
# /wiki/List_of_German_states_by_population
# /wiki/List_of_German_states_by_population_density
# /wiki/List_of_German_states_by_unemployment_rate
# /wiki/List_of_states_in_the_Holy_Roman_Empire
# /wiki/List_of_subnational_entities
# /wiki/States_of_Austria
# /w/index.php?title=States_of_Germany&action=edit&section=19
# #cite_ref-3
# /wiki/Loan_word
# /wiki/Basic_Law_for_the_Federal_Republic_of_Germany
# #cite_note-1
# #cite_note-2
# /wiki/Federal_state
# /wiki/Federated_state
# /wiki/Bavaria
# /wiki/Saxony
# /wiki/Thuringia
# /wiki/Freistaat
# /w/index.php?title=States_of_Germany&action=edit&section=20
# #cite_ref-1
# /wiki/Christian_Tomuschat
# /wiki/David_P._Currie
# https://www.btg-bestellservice.de/pdf/80201000.pdf
# /wiki/Deutscher_Bundestag
# #cite_ref-2
# /wiki/House_of_Commons_of_the_United_Kingdom
# https://www.theyworkforyou.com/debates/?id=1991-02-28a.1145.0&s=%22german+land+of%22#g1203.1
# /wiki/UK_parliament
# #cite_ref-4
# http://library.fes.de/fulltext/bueros/london/00538007.htm
# /wiki/Friedrich_Ebert_Foundation
# #cite_ref-5
# http://www.germanlawjournal.com/pdfs/Vol06No10/PDF_Vol_06_No_10_1283-1296_SI_Articles_Gunlicks.pdf
# https://web.archive.org/web/20110621215821/http://www.germanlawjournal.com/pdfs/Vol06No10/PDF_Vol_06_No_10_1283-1296_SI_Articles_Gunlicks.pdf
# /wiki/Wayback_Machine
# #cite_ref-6
# #cite_ref-7
# #cite_ref-8
# http://citypopulation.de/en/germany/cities/
# #cite_ref-9
# https://globaldatalab.org/shdi/shdi/
# #cite_ref-10
# https://www.statistikportal.de/en
# https://www.statistikportal.de/en
# /wiki/Help:CS1_errors#param_has_ext_link
# #cite_ref-11
# /wiki/South_Baden
# /wiki/W%C3%BCrttemberg-Baden
# /wiki/W%C3%BCrttemberg-Hohenzollern
# #cite_ref-12
# /wiki/German_reunification
# /wiki/West_Berlin
# /wiki/West_Germany
# #cite_ref-13
# https://books.google.com/books?id=Q40tDwAAQBAJ
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9781847790323
# https://books.google.com/books?id=_XaFaNshCrkC
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780674926851
# https://books.google.com/books?id=riBpAAAAMAAJ
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780880331746
# #cite_ref-14
# http://www.cvce.eu/viewer/-/content/26859090-52d0-4850-9019-92748182042a/en;jsessionid=D56ABFCD5B07575A729089229C359CD3
# #cite_ref-15
# https://www.btg-bestellservice.de/pdf/80201000.pdf
# /w/index.php?title=States_of_Germany&action=edit&section=21
# http://www.citymayors.com/government/germany_government.html
# /wiki/Template:States_of_the_Federal_Republic_of_Germany
# /wiki/Template_talk:States_of_the_Federal_Republic_of_Germany
# https://en.wikipedia.org/w/index.php?title=Template:States_of_the_Federal_Republic_of_Germany&action=edit
# /wiki/Germany
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Bavaria
# /wiki/Brandenburg
# /wiki/Hesse
# /wiki/Lower_Saxony
# /wiki/Mecklenburg-Vorpommern
# /wiki/North_Rhine-Westphalia
# /wiki/Rhineland-Palatinate
# /wiki/Saarland
# /wiki/Saxony
# /wiki/Saxony-Anhalt
# /wiki/Schleswig-Holstein
# /wiki/Thuringia
# /wiki/File:States_of_Germany.svg
# /wiki/Berlin
# /wiki/Bremen_(state)
# /wiki/Hamburg
# /wiki/South_Baden
# /wiki/W%C3%BCrttemberg-Baden
# /wiki/W%C3%BCrttemberg-Hohenzollern
# /wiki/Template:Allied-administered_Germany
# /wiki/Template_talk:Allied-administered_Germany
# https://en.wikipedia.org/w/index.php?title=Template:Allied-administered_Germany&action=edit
# /wiki/File:Merchant_flag_of_Germany_(1946%E2%80%931949).svg
# /wiki/Allied-occupied_Germany
# /wiki/Allied-occupied_Germany#American_Zone_of_Occupation
# /wiki/United_States
# /wiki/Bavaria
# /wiki/Bremen_(state)
# /wiki/Hesse
# /wiki/Greater_Hesse
# /wiki/W%C3%BCrttemberg-Baden
# /wiki/File:Deutschland_Besatzungszonen_8_Jun_1947_-_22_Apr_1949.svg
# /wiki/Allied-occupied_Germany#British_Zone_of_Occupation
# /wiki/United_Kingdom
# /wiki/Lower_Saxony
# /wiki/State_of_Hanover
# /wiki/Hamburg
# /wiki/North_Rhine-Westphalia
# /wiki/Schleswig-Holstein
# /wiki/Allied-occupied_Germany#French_Zone_of_Occupation
# /wiki/France
# /wiki/South_Baden
# /wiki/Rhineland-Palatinate
# /wiki/W%C3%BCrttemberg-Hohenzollern
# /wiki/Soviet_occupation_zone
# /wiki/Soviet_Union
# /wiki/Brandenburg_(1945%E2%80%931952)
# /wiki/Mecklenburg_(1945%E2%80%931952)
# /wiki/Saxony
# /wiki/Saxony-Anhalt_(1945%E2%80%931952)
# /wiki/Thuringia
# /wiki/Berlin
# /wiki/West_Berlin
# /wiki/East_Berlin
# /wiki/Saarland
# /wiki/Saar_Protectorate
# /wiki/Template:Orders,_decorations,_and_medals_of_Germany
# /wiki/Template_talk:Orders,_decorations,_and_medals_of_Germany
# https://en.wikipedia.org/w/index.php?title=Template:Orders,_decorations,_and_medals_of_Germany&action=edit
# /wiki/Germany
# /wiki/Orders,_decorations,_and_medals_of_the_German_states
# /wiki/Order_of_merit
# /wiki/Germany
# /wiki/Order_of_Merit_of_the_Federal_Republic_of_Germany
# /wiki/File:Coat_of_arms_of_Germany.svg
# /wiki/Order_of_merit
# /wiki/Order_of_Merit_of_Baden-W%C3%BCrttemberg
# /wiki/Bavarian_Order_of_Merit
# /wiki/Order_of_Merit_of_Berlin
# /wiki/Order_of_Merit_of_Brandenburg
# /wiki/Hessian_Order_of_Merit
# /wiki/Order_of_Merit_of_Mecklenburg-Vorpommern
# /wiki/Lower_Saxony_Order_of_Merit
# /wiki/Order_of_Merit_of_North_Rhine-Westphalia
# /wiki/Order_of_Merit_of_Rhineland-Palatinate
# /wiki/Verdienstmedaille_des_Landes_Rheinland-Pfalz
# /wiki/Saarland_Order_of_Merit
# /wiki/Order_of_Merit_of_the_Free_State_of_Saxony
# /wiki/Order_of_Merit_of_Saxony-Anhalt
# /wiki/Order_of_Merit_of_Schleswig-Holstein
# /wiki/Order_of_Merit_of_the_Free_State_of_Thuringia
# /wiki/Bavarian_Maximilian_Order_for_Science_and_Art
# /wiki/Pour_le_M%C3%A9rite
# /wiki/Template:Germany_topics
# /wiki/Template_talk:Germany_topics
# https://en.wikipedia.org/w/index.php?title=Template:Germany_topics&action=edit
# /wiki/Germany
# /wiki/Index_of_Germany-related_articles
# /wiki/History_of_Germany
# /wiki/Timeline_of_German_history
# /wiki/Historiography_of_Germany
# /wiki/Military_history_of_Germany
# /wiki/Germanic_peoples
# /wiki/Migration_Period
# /wiki/Francia
# /wiki/Holy_Roman_Empire
# /wiki/Ostsiedlung
# /wiki/Germany_in_the_early_modern_period
# /wiki/18th-century_history_of_Germany
# /wiki/Confederation_of_the_Rhine
# /wiki/German_Confederation
# /wiki/Frankfurt_Constitution
# /wiki/North_German_Confederation
# /wiki/Unification_of_Germany
# /wiki/German_Empire
# /wiki/History_of_Germany_during_World_War_I
# /wiki/German_Revolution_of_1918%E2%80%9319
# /wiki/Weimar_Republic
# /wiki/Nazi_Germany
# /wiki/Nazi_Germany#World_War_II
# /wiki/History_of_Germany_(1945%E2%80%931990)
# /wiki/Allied-occupied_Germany
# /wiki/Flight_and_expulsion_of_Germans_(1944%E2%80%931950)
# /wiki/East_Germany
# /wiki/West_Germany
# /wiki/German_reunification
# /wiki/History_of_Germany_since_1990
# /wiki/Germany
# /wiki/Geography_of_Germany
# /wiki/Administrative_divisions_of_Germany
# /wiki/Districts_of_Germany
# /wiki/List_of_cities_and_towns_in_Germany
# /wiki/List_of_earthquakes_in_Germany
# /wiki/Geology_of_Germany
# /wiki/List_of_islands_of_Germany
# /wiki/List_of_lakes_of_Germany
# /wiki/Category:Mountains_of_Germany
# /wiki/Category:Rivers_of_Germany
# /wiki/Politics_of_Germany
# /wiki/Bundestag
# /wiki/Bundesrat_of_Germany
# /wiki/Bundeswehr
# /wiki/Cabinet_of_Germany
# /wiki/Chancellor_of_Germany_(1949%E2%80%93)
# /wiki/Basic_Law_for_the_Federal_Republic_of_Germany
# /wiki/Judiciary_of_Germany
# /wiki/Elections_in_Germany
# /wiki/Foreign_relations_of_Germany
# /wiki/Human_rights_in_Germany
# /wiki/Intersex_rights_in_Germany
# /wiki/LGBT_rights_in_Germany
# /wiki/Transgender_rights_in_Germany
# /wiki/Law_of_Germany
# /wiki/Law_enforcement_in_Germany
# /wiki/List_of_political_parties_in_Germany
# /wiki/President_of_Germany
# /wiki/Economy_of_Germany
# /wiki/Agriculture_in_Germany
# /wiki/Automotive_industry_in_Germany
# /wiki/Banking_in_Germany
# /wiki/Deutsche_Bundesbank
# /wiki/Middle_German_Chemical_Triangle
# /wiki/Economic_history_of_Germany
# /wiki/Energy_in_Germany
# /wiki/List_of_exports_of_Germany
# /wiki/German_model
# /wiki/List_of_German_states_by_GDP
# /wiki/Mittelstand
# /wiki/Science_and_technology_in_Germany
# /wiki/Frankfurt_Stock_Exchange
# /wiki/Taxation_in_Germany
# /wiki/Telecommunications_in_Germany
# /wiki/Tourism_in_Germany
# /wiki/Trade_unions_in_Germany
# /wiki/Transport_in_Germany
# /wiki/Welfare_in_Germany
# /wiki/Category:German_society
# /wiki/Crime_in_Germany
# /wiki/Demographics_of_Germany
# /wiki/Drug_policy_of_Germany
# /wiki/Education_in_Germany
# /wiki/Germans
# /wiki/Category:Ethnic_groups_in_Germany
# /wiki/Healthcare_in_Germany
# /wiki/Immigration_to_Germany
# /wiki/Pensions_in_Germany
# /wiki/Religion_in_Germany
# /wiki/Social_issues_in_Germany
# /wiki/Culture_of_Germany
# /wiki/Deutschlandlied
# /wiki/Architecture_of_Germany
# /wiki/German_art
# /wiki/Category:Arts_in_Germany
# /wiki/Cinema_of_Germany
# /wiki/Coat_of_arms_of_Germany
# /wiki/German_cuisine
# /wiki/List_of_cultural_icons_of_Germany
# /wiki/Category:Dance_in_Germany
# /wiki/German_fashion
# /wiki/Category:Festivals_in_Germany
# /wiki/Flag_of_Germany
# /wiki/German_language
# /wiki/List_of_libraries_in_Germany
# /wiki/German_literature
# /wiki/Internet_in_Germany
# /wiki/Media_of_Germany
# /wiki/Music_of_Germany
# /wiki/Names_of_Germany
# /wiki/German_philosophy
# /wiki/Prussian_virtues
# /wiki/Sport_in_Germany
# /wiki/Television_in_Germany
# /wiki/List_of_World_Heritage_Sites_in_Germany
# /wiki/Outline_of_Germany
# /wiki/Index_of_Germany-related_articles
# /wiki/Category:Germany
# /wiki/Portal:Germany
# /wiki/Template:Europe_topic
# /wiki/Template_talk:Europe_topic
# https://en.wikipedia.org/w/index.php?title=Template:Europe_topic&action=edit
# /wiki/Subdivisions_of_Albania
# /wiki/Subdivisions_of_Andorra
# /wiki/Subdivisions_of_Armenia
# /wiki/Subdivisions_of_Austria
# /wiki/Subdivisions_of_Azerbaijan
# /wiki/Subdivisions_of_Belarus
# /wiki/Subdivisions_of_Belgium
# /wiki/Subdivisions_of_Bosnia_and_Herzegovina
# /wiki/Subdivisions_of_Bulgaria
# /wiki/Subdivisions_of_Croatia
# /wiki/Subdivisions_of_Cyprus
# /wiki/Subdivisions_of_the_Czech_Republic
# /wiki/Subdivisions_of_Denmark
# /wiki/Subdivisions_of_Estonia
# /wiki/Subdivisions_of_Finland
# /wiki/Subdivisions_of_France
# /wiki/Subdivisions_of_Georgia_(country)
# /wiki/Subdivisions_of_Germany
# /wiki/Subdivisions_of_Greece
# /wiki/Subdivisions_of_Hungary
# /wiki/Subdivisions_of_Iceland
# /wiki/Subdivisions_of_the_Republic_of_Ireland
# /wiki/Subdivisions_of_Italy
# /wiki/Subdivisions_of_Kazakhstan
# /wiki/Subdivisions_of_Latvia
# /wiki/Subdivisions_of_Liechtenstein
# /wiki/Subdivisions_of_Lithuania
# /wiki/Subdivisions_of_Luxembourg
# /wiki/Subdivisions_of_Malta
# /wiki/Subdivisions_of_Moldova
# /wiki/Subdivisions_of_Monaco
# /wiki/Subdivisions_of_Montenegro
# /wiki/Subdivisions_of_the_Netherlands
# /wiki/Subdivisions_of_North_Macedonia
# /wiki/Subdivisions_of_Norway
# /wiki/Subdivisions_of_Poland
# /wiki/Subdivisions_of_Portugal
# /wiki/Subdivisions_of_Romania
# /wiki/Subdivisions_of_Russia
# /wiki/Subdivisions_of_San_Marino
# /wiki/Subdivisions_of_Serbia
# /wiki/Subdivisions_of_Slovakia
# /wiki/Subdivisions_of_Slovenia
# /wiki/Subdivisions_of_Spain
# /wiki/Subdivisions_of_Sweden
# /wiki/Subdivisions_of_Switzerland
# /wiki/Subdivisions_of_Turkey
# /wiki/Subdivisions_of_Ukraine
# /wiki/Subdivisions_of_the_United_Kingdom
# /wiki/Subdivisions_of_Abkhazia
# /w/index.php?title=Subdivisions_of_the_Republic_of_Artsakh&action=edit&redlink=1
# /wiki/Subdivisions_of_Kosovo
# /wiki/Subdivisions_of_Northern_Cyprus
# /wiki/Subdivisions_of_South_Ossetia
# /w/index.php?title=Subdivisions_of_Transnistria&action=edit&redlink=1
# /wiki/Subdivisions_of_%C3%85land
# /wiki/Subdivisions_of_the_Faroe_Islands
# /w/index.php?title=Subdivisions_of_Gibraltar&action=edit&redlink=1
# /wiki/Subdivisions_of_Guernsey
# /wiki/Subdivisions_of_the_Isle_of_Man
# /wiki/Subdivisions_of_Jersey
# /w/index.php?title=Subdivisions_of_Svalbard&action=edit&redlink=1
# /wiki/Template:Articles_on_first-level_administrative_divisions_of_European_countries
# /wiki/Template_talk:Articles_on_first-level_administrative_divisions_of_European_countries
# https://en.wikipedia.org/w/index.php?title=Template:Articles_on_first-level_administrative_divisions_of_European_countries&action=edit
# /wiki/Administrative_division
# /wiki/Europe
# /wiki/Sovereign_state
# /wiki/Counties_of_Albania
# /wiki/Parishes_of_Andorra
# /wiki/Administrative_divisions_of_Armenia
# /wiki/States_of_Austria
# /wiki/Administrative_divisions_of_Azerbaijan
# /wiki/Regions_of_Belarus
# /wiki/Communities,_regions_and_language_areas_of_Belgium
# /wiki/Political_divisions_of_Bosnia_and_Herzegovina
# /wiki/Provinces_of_Bulgaria
# /wiki/Counties_of_Croatia
# /wiki/Districts_of_Cyprus
# /wiki/Regions_of_the_Czech_Republic
# /wiki/Regions_of_Denmark
# /wiki/Counties_of_Estonia
# /wiki/Regions_of_Finland
# /wiki/Regions_of_France
# /wiki/Administrative_divisions_of_Georgia_(country)
# /wiki/Administrative_regions_of_Greece
# /wiki/Counties_of_Hungary
# /wiki/Regions_of_Iceland
# /wiki/Local_government_in_the_Republic_of_Ireland
# /wiki/Regions_of_Italy
# /wiki/Regions_of_Kazakhstan
# /wiki/Administrative_divisions_of_Latvia
# /wiki/Municipalities_of_Liechtenstein
# /wiki/Counties_of_Lithuania
# /wiki/Cantons_of_Luxembourg
# /wiki/Local_councils_of_Malta
# /wiki/Administrative_divisions_of_Moldova
# /wiki/Monaco#Administrative_divisions
# /wiki/Municipalities_of_Montenegro
# /wiki/Provinces_of_the_Netherlands
# /wiki/Municipalities_of_North_Macedonia
# /wiki/Counties_of_Norway
# /wiki/Voivodeships_of_Poland
# /wiki/Administrative_divisions_of_Portugal
# /wiki/Counties_of_Romania
# /wiki/Federal_subjects_of_Russia
# /wiki/Municipalities_of_San_Marino
# /wiki/Districts_of_Serbia
# /wiki/Regions_of_Slovakia
# /wiki/Municipalities_of_Slovenia
# /wiki/Autonomous_communities_of_Spain
# /wiki/Counties_of_Sweden
# /wiki/Cantons_of_Switzerland
# /wiki/Provinces_of_Turkey
# /wiki/Administrative_divisions_of_Ukraine
# /wiki/Administrative_geography_of_the_United_Kingdom
# /wiki/List_of_states_with_limited_recognition
# /wiki/Districts_of_Abkhazia
# /wiki/Administrative_divisions_of_the_Republic_of_Artsakh
# /wiki/Municipalities_of_Kosovo
# /wiki/Districts_of_Northern_Cyprus
# /wiki/Administrative_divisions_of_South_Ossetia
# /wiki/Administrative_divisions_of_Transnistria
# /wiki/List_of_administrative_divisions_by_country
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q1221156#identifiers
# /wiki/GND_(identifier)
# https://d-nb.info/gnd/4034013-2
# /wiki/LCCN_(identifier)
# https://id.loc.gov/authorities/subjects/sh2007002590
# https://en.wikipedia.org/w/index.php?title=States_of_Germany&oldid=994235232
# /wiki/Help:Category
# /wiki/Category:States_of_Germany
# /wiki/Category:Subdivisions_of_Germany
# /wiki/Category:Lists_of_subdivisions_of_Germany
# /wiki/Category:Country_subdivisions_in_Europe
# /wiki/Category:First-level_administrative_country_subdivisions
# /wiki/Category:Germany_geography-related_lists
# /wiki/Category:States_of_Germany-related_lists
# /wiki/Category:Articles_containing_German-language_text
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:CS1_errors:_external_links
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Articles_needing_additional_references_from_November_2019
# /wiki/Category:All_articles_needing_additional_references
# /wiki/Category:Wikipedia_articles_needing_reorganization_from_November_2019
# /wiki/Category:Articles_with_multiple_maintenance_issues
# /wiki/Category:Articles_containing_Latin-language_text
# /wiki/Category:Articles_containing_potentially_dated_statements_from_March_2009
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=States+of+Germany
# /w/index.php?title=Special:UserLogin&returnto=States+of+Germany
# /wiki/States_of_Germany
# /wiki/Talk:States_of_Germany
# /wiki/States_of_Germany
# /w/index.php?title=States_of_Germany&action=edit
# /w/index.php?title=States_of_Germany&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/States_of_Germany
# /wiki/Special:RecentChangesLinked/States_of_Germany
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=States_of_Germany&oldid=994235232
# /w/index.php?title=States_of_Germany&action=info
# /w/index.php?title=Special:CiteThisPage&page=States_of_Germany&id=994235232&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q1221156
# /w/index.php?title=Special:DownloadAsPdf&page=States_of_Germany&action=show-download-screen
# /w/index.php?title=States_of_Germany&printable=yes
# https://commons.wikimedia.org/wiki/Category:States_of_Germany
# https://af.wikipedia.org/wiki/Deelstate_van_Duitsland
# https://als.wikipedia.org/wiki/Land_(Deutschland)
# https://am.wikipedia.org/wiki/%E1%8B%A8%E1%8C%80%E1%88%AD%E1%88%98%E1%8A%95_%E1%8A%AD%E1%8D%8D%E1%88%8B%E1%8C%88%E1%88%AB%E1%89%B5
# https://ar.wikipedia.org/wiki/%D9%88%D9%84%D8%A7%D9%8A%D8%A7%D8%AA_%D8%A3%D9%84%D9%85%D8%A7%D9%86%D9%8A%D8%A7
# https://an.wikipedia.org/wiki/Estatos_d%27Alemanya
# https://ast.wikipedia.org/wiki/Estaos_d%27Alema%C3%B1a
# https://az.wikipedia.org/wiki/Torpaq_(Almaniya)
# https://zh-min-nan.wikipedia.org/wiki/Tek-kok_%C3%AA_h%C3%AAng-ch%C3%A8ng-khu
# https://ba.wikipedia.org/wiki/%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D1%8F_%D0%B5%D1%80%D2%99%D3%99%D1%80%D0%B5
# https://be.wikipedia.org/wiki/%D0%97%D0%B5%D0%BC%D0%BB%D1%96_%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D1%96%D1%96
# https://be-tarask.wikipedia.org/wiki/%D0%90%D0%B4%D0%BC%D1%96%D0%BD%D1%96%D1%81%D1%82%D1%80%D0%B0%D1%86%D1%8B%D0%B9%D0%BD%D0%B0-%D1%82%D1%8D%D1%80%D1%8B%D1%82%D0%B0%D1%80%D1%8B%D1%8F%D0%BB%D1%8C%D0%BD%D1%8B_%D0%BF%D0%B0%D0%B4%D0%B7%D0%B5%D0%BB_%D0%9D%D1%8F%D0%BC%D0%B5%D1%87%D1%87%D1%8B%D0%BD%D1%8B
# https://bg.wikipedia.org/wiki/%D0%A4%D0%B5%D0%B4%D0%B5%D1%80%D0%B0%D0%BB%D0%BD%D0%B8_%D0%BF%D1%80%D0%BE%D0%B2%D0%B8%D0%BD%D1%86%D0%B8%D0%B8_%D0%BD%D0%B0_%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D1%8F
# https://bar.wikipedia.org/wiki/Bundesland_(Deitschland)
# https://bs.wikipedia.org/wiki/Njema%C4%8Dke_savezne_pokrajine
# https://br.wikipedia.org/wiki/Stado%C3%B9_Alamagn
# https://ca.wikipedia.org/wiki/Estat_federat_alemany
# https://cv.wikipedia.org/wiki/%D0%A4%D0%B5%D0%B4%D0%B5%D1%80%D0%B0%D1%86%D0%B8_%C3%A7%C4%95%D1%80%C4%95_(%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8)
# https://cs.wikipedia.org/wiki/N%C4%9Bmeck%C3%A9_spolkov%C3%A9_zem%C4%9B
# https://co.wikipedia.org/wiki/Land_(Germania)
# https://cy.wikipedia.org/wiki/Taleithiau_ffederal_yr_Almaen
# https://da.wikipedia.org/wiki/Tysklands_delstater
# https://pdc.wikipedia.org/wiki/Bunnesland
# https://de.wikipedia.org/wiki/Land_(Deutschland)
# https://et.wikipedia.org/wiki/Liidumaa
# https://el.wikipedia.org/wiki/%CE%9F%CE%BC%CF%8C%CF%83%CF%80%CE%BF%CE%BD%CE%B4%CE%B1_%CE%BA%CF%81%CE%B1%CF%84%CE%AF%CE%B4%CE%B9%CE%B1_%CF%84%CE%B7%CF%82_%CE%93%CE%B5%CF%81%CE%BC%CE%B1%CE%BD%CE%AF%CE%B1%CF%82
# https://es.wikipedia.org/wiki/Estado_federado_(Alemania)
# https://eo.wikipedia.org/wiki/Federacia_lando_(Germanio)
# https://eu.wikipedia.org/wiki/Alemaniako_estatuak
# https://fa.wikipedia.org/wiki/%D8%A7%DB%8C%D8%A7%D9%84%D8%AA%E2%80%8C%D9%87%D8%A7%DB%8C_%D8%A2%D9%84%D9%85%D8%A7%D9%86
# https://fr.wikipedia.org/wiki/Land_(Allemagne)
# https://fy.wikipedia.org/wiki/Dielsteaten_fan_D%C3%BAtsl%C3%A2n
# https://gv.wikipedia.org/wiki/Steatyn_ny_Germaan
# https://gl.wikipedia.org/wiki/Estados_de_Alema%C3%B1a
# https://xal.wikipedia.org/wiki/%D0%9D%D0%B5%D0%BC%D1%88%D0%B8%D0%BD_%D0%BE%D1%80%D0%BD%D0%B0_%D3%99%D2%A3%D0%B3%D0%B8%D0%BD_%D1%83%D0%BB%D1%83%D1%81
# https://ko.wikipedia.org/wiki/%EB%8F%85%EC%9D%BC%EC%9D%98_%EC%A3%BC
# https://hy.wikipedia.org/wiki/%D5%86%D5%A1%D5%B0%D5%A1%D5%B6%D5%A3_(%D4%B3%D5%A5%D6%80%D5%B4%D5%A1%D5%B6%D5%AB%D5%A1)
# https://hr.wikipedia.org/wiki/Njema%C4%8Dke_savezne_pokrajine
# https://io.wikipedia.org/wiki/Stati_di_Germania
# https://id.wikipedia.org/wiki/Negara_bagian_di_Jerman
# https://ia.wikipedia.org/wiki/Stato_federal_(Germania)
# https://os.wikipedia.org/wiki/%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D1%8B_%D0%B7%C3%A6%D1%85%D1%85%D1%8B%D1%82%C3%A6
# https://it.wikipedia.org/wiki/Stati_federati_della_Germania
# https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%99%D7%A0%D7%95%D7%AA_%D7%92%D7%A8%D7%9E%D7%A0%D7%99%D7%94
# https://jv.wikipedia.org/wiki/Dhaptar_negara_bag%C3%A9an_Jerman
# https://pam.wikipedia.org/wiki/States_ning_Germany
# https://ka.wikipedia.org/wiki/%E1%83%92%E1%83%94%E1%83%A0%E1%83%9B%E1%83%90%E1%83%9C%E1%83%98%E1%83%98%E1%83%A1_%E1%83%A4%E1%83%94%E1%83%93%E1%83%94%E1%83%A0%E1%83%90%E1%83%9A%E1%83%A3%E1%83%A0%E1%83%98_%E1%83%9B%E1%83%AE%E1%83%90%E1%83%A0%E1%83%94%E1%83%94%E1%83%91%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D1%8F_%D0%B6%D0%B5%D1%80%D0%BB%D0%B5%D1%80%D1%96
# https://sw.wikipedia.org/wiki/Majimbo_ya_Ujerumani
# https://ku.wikipedia.org/wiki/Her%C3%AAm%C3%AAn_Almanyay%C3%AA
# https://la.wikipedia.org/wiki/Terra_foederalis_(Germania)
# https://lv.wikipedia.org/wiki/V%C4%81cijas_feder%C4%81l%C4%81s_zemes
# https://lb.wikipedia.org/wiki/Land_(D%C3%A4itschland)
# https://lt.wikipedia.org/wiki/Vokietijos_%C5%BEem%C4%97s
# https://lfn.wikipedia.org/wiki/Statos_de_Deutxland
# https://lmo.wikipedia.org/wiki/Land_(Jermania)
# https://hu.wikipedia.org/wiki/N%C3%A9metorsz%C3%A1g_tartom%C3%A1nyai
# https://mk.wikipedia.org/wiki/%D0%A1%D0%BE%D1%98%D1%83%D0%B7%D0%BD%D0%B8_%D0%BF%D0%BE%D0%BA%D1%80%D0%B0%D0%B8%D0%BD%D0%B8_%D0%B2%D0%BE_%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D1%98%D0%B0
# https://mr.wikipedia.org/wiki/%E0%A4%9C%E0%A4%B0%E0%A5%8D%E0%A4%AE%E0%A4%A8%E0%A5%80%E0%A4%9A%E0%A5%80_%E0%A4%B0%E0%A4%BE%E0%A4%9C%E0%A5%8D%E0%A4%AF%E0%A5%87
# https://ms.wikipedia.org/wiki/Negeri_di_Jerman
# https://nl.wikipedia.org/wiki/Deelstaten_van_Duitsland
# https://nds-nl.wikipedia.org/wiki/Deelstoaten_van_Duutslaand
# https://ja.wikipedia.org/wiki/%E3%83%89%E3%82%A4%E3%83%84%E3%81%AE%E5%9C%B0%E6%96%B9%E8%A1%8C%E6%94%BF%E5%8C%BA%E5%88%86
# https://ce.wikipedia.org/wiki/%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D0%BD_%D0%BB%D0%B0%D1%82%D1%82%D0%B0%D0%BD%D0%B0%D1%88
# https://no.wikipedia.org/wiki/Tysklands_delstater
# https://nn.wikipedia.org/wiki/Delstatar_i_Tyskland
# https://nov.wikipedia.org/wiki/Liste_de_germani_federali_landes
# https://oc.wikipedia.org/wiki/Land_(Alemanha)
# https://uz.wikipedia.org/wiki/Germaniya_yerlari
# https://pa.wikipedia.org/wiki/%E0%A8%9C%E0%A8%B0%E0%A8%AE%E0%A8%A8%E0%A9%80_%E0%A8%A6%E0%A9%87_%E0%A8%B0%E0%A8%BE%E0%A8%9C
# https://pfl.wikipedia.org/wiki/Land_(Deutschland)
# https://nds.wikipedia.org/wiki/Bundsland_(D%C3%BC%C3%BCtschland)
# https://pl.wikipedia.org/wiki/Kraje_zwi%C4%85zkowe_Niemiec
# https://pt.wikipedia.org/wiki/Estados_da_Alemanha
# https://ksh.wikipedia.org/wiki/Bundesland_(D%C3%BCtschland)
# https://ro.wikipedia.org/wiki/Landurile_Germaniei
# https://ru.wikipedia.org/wiki/%D0%97%D0%B5%D0%BC%D0%BB%D0%B8_%D0%93%D0%B5%D1%80%D0%BC%D0%B0%D0%BD%D0%B8%D0%B8
# https://sc.wikipedia.org/wiki/Istados_federados_de_Germ%C3%A0nia
# https://sco.wikipedia.org/wiki/States_o_Germany
# https://sq.wikipedia.org/wiki/Nj%C3%ABsit%C3%AB_federative_t%C3%AB_Gjermanis%C3%AB
# https://scn.wikipedia.org/wiki/Land
# https://si.wikipedia.org/wiki/%E0%B6%A2%E0%B6%BB%E0%B7%8A%E0%B6%B8%E0%B6%B1%E0%B7%92%E0%B6%BA%E0%B7%9A_%E0%B6%B4%E0%B7%8A%E2%80%8D%E0%B6%BB%E0%B7%8F%E0%B6%B1%E0%B7%8A%E0%B6%AD%E0%B6%BA%E0%B6%B1%E0%B7%8A
# https://simple.wikipedia.org/wiki/States_of_Germany
# https://sd.wikipedia.org/wiki/%D8%AC%D8%B1%D9%85%D9%86%D9%8A%D8%A1%D9%8E_%D8%AC%D9%88%D9%86_%D8%B1%D9%8A%D8%A7%D8%B3%D8%AA%D9%88%D9%86
# https://sk.wikipedia.org/wiki/Krajina_(Nemecko)
# https://sl.wikipedia.org/wiki/Nem%C5%A1ka_zvezna_de%C5%BEela
# https://ckb.wikipedia.org/wiki/%D9%88%DB%8C%D9%84%D8%A7%DB%8C%DB%95%D8%AA%DB%95%DA%A9%D8%A7%D9%86%DB%8C_%D8%A6%DB%95%DA%B5%D9%85%D8%A7%D9%86%DB%8C%D8%A7
# https://sr.wikipedia.org/wiki/%D0%94%D1%80%D0%B6%D0%B0%D0%B2%D0%B5_%D0%8A%D0%B5%D0%BC%D0%B0%D1%87%D0%BA%D0%B5
# https://sh.wikipedia.org/wiki/Njema%C4%8Dke_pokrajine
# https://fi.wikipedia.org/wiki/Saksan_osavaltiot
# https://sv.wikipedia.org/wiki/Tysklands_f%C3%B6rbundsl%C3%A4nder
# https://tl.wikipedia.org/wiki/L%C3%A4nder_ng_Alemanya
# https://ta.wikipedia.org/wiki/%E0%AE%87%E0%AE%9F%E0%AE%BE%E0%AE%AF%E0%AF%8D%E0%AE%9A%E0%AF%8D%E0%AE%9A%E0%AF%81%E0%AE%B2%E0%AE%BE%E0%AE%A8%E0%AF%8D%E0%AE%A4%E0%AE%BF%E0%AE%A9%E0%AF%8D_%E0%AE%AE%E0%AE%BE%E0%AE%A8%E0%AE%BF%E0%AE%B2%E0%AE%99%E0%AF%8D%E0%AE%95%E0%AE%B3%E0%AF%8D
# https://th.wikipedia.org/wiki/%E0%B8%A3%E0%B8%B1%E0%B8%90%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%80%E0%B8%A2%E0%B8%AD%E0%B8%A3%E0%B8%A1%E0%B8%99%E0%B8%B5
# https://tr.wikipedia.org/wiki/Almanya%27n%C4%B1n_eyaletleri
# https://uk.wikipedia.org/wiki/%D0%97%D0%B5%D0%BC%D0%BB%D1%96_%D0%9D%D1%96%D0%BC%D0%B5%D1%87%D1%87%D0%B8%D0%BD%D0%B8
# https://ur.wikipedia.org/wiki/%D8%AC%D8%B1%D9%85%D9%86%DB%8C_%DA%A9%DB%8C_%D8%B1%DB%8C%D8%A7%D8%B3%D8%AA%DB%8C%DA%BA
# https://vec.wikipedia.org/wiki/Stati_federai_de_%C5%82a_Xerm%C3%A0nia
# https://vi.wikipedia.org/wiki/Bang_(%C4%90%E1%BB%A9c)
# https://vls.wikipedia.org/wiki/D%C3%AAelstoat_(Duutsland)
# https://war.wikipedia.org/wiki/Mga_estado_han_Alemanya
# https://wuu.wikipedia.org/wiki/%E8%81%94%E9%82%A6%E5%B7%9E_(%E5%BE%B7%E5%9B%BD)
# https://yi.wikipedia.org/wiki/%D7%93%D7%99%D7%99%D7%98%D7%A9%D7%A2_%D7%9C%D7%A2%D7%A0%D7%93%D7%A2%D7%A8
# https://yo.wikipedia.org/wiki/%C3%80w%E1%BB%8Dn_%C3%8Cp%C3%ADnl%E1%BA%B9%CC%80_J%E1%BA%B9%CC%81m%C3%A1n%C3%AC
# https://zh-yue.wikipedia.org/wiki/%E5%BE%B7%E5%9C%8B%E5%90%84%E8%81%AF%E9%82%A6%E5%B7%9E
# https://diq.wikipedia.org/wiki/Eyalet%C3%AA_Almanya
# https://zh.wikipedia.org/wiki/%E8%81%94%E9%82%A6%E5%B7%9E_(%E5%BE%B7%E5%9B%BD)
# https://www.wikidata.org/wiki/Special:EntityPage/Q1221156#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=States_of_Germany&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# Finally, we will look for the ``table`` attribute with the class ``sortable wikitable`` with ``tr``

# %%
# First find the right table by using the class_ tag (similar to css tags)

right_table = soup.find('table', class_="sortable wikitable").findAll('tr')

# find all tags start with td

states = []

for row in right_table:
    state_data_entry = row.findAll('td')
    if(len(state_data_entry)!=0):
        states.append(state_data_entry[2].find(text=True))
print(states)
# Out:
# ['Baden-Württemberg', 'Bavaria', 'Berlin', 'Brandenburg', 'Bremen', 'Hamburg', 'Hesse', 'Lower Saxony', 'Mecklenburg-Vorpommern', 'North Rhine-', 'Rhineland-Palatinate', 'Saarland', 'Saxony', 'Saxony-Anhalt', 'Schleswig-Holstein', 'Thuringia']

# %% [markdown]
# In this task we will use the same Wikipedia page to create the following dataframe columns filled with statiscal data for each German state
#
# ['STATE','SINCE','CAPITAL','LEGISLATURE','HEAD_OF_GOVERNMENT','GOVERNMENT_COALITION','BUNDES_RAT_VOTES','AREA_KM_SQUARE','POPULATION','POP_PER_KM_SQ','CAPITAL','HUMAN_DEVELOPMENT_INDEX','GDP_PER_CAPITA']

# %%
#import the library used to query a website
import requests

# import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup
import time


#specify the url

wiki = "https://en.wikipedia.org/wiki/States_of_Germany"

#Query the website and return the html to the variable 'page'
page = requests.get(wiki)

# Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(page.text,'html.parser')


right_table = soup.find('table', class_="sortable wikitable")



# Generate lists
TABLE_COLS = []
STATE = []
SINCE = []
CAPITAL=[]
LEGISLATURE=[]
HEAD_OF_GOVERNMENT = []
GOVERNMENT_COALITION = []
BUNDES_RAT_VOTES = []
AREA_KM_SQUARE = []
POPULATION = []
POP_PER_KM_SQ = []
HUMAN_DEVELOPMENT_INDEX = []
GDP_PER_CAPITA = []

for row in right_table.find_all("tr"):
    cells = row.find_all("th") # to store col names
    states = row.find_all("td") # to store state values

    if len(cells) == 14:
    # append the name of the cols
      for col in cells:
        TABLE_COLS.append(col.find(text=True))

    if len(states)!=0:
        STATE.append(states[2].find(text=True))
        SINCE.append(states[3].find(text=True))
        CAPITAL.append(states[4].find(text=True))
        LEGISLATURE.append(states[5].find(text=True))
        HEAD_OF_GOVERNMENT.append(states[6].find(text=True))
        GOVERNMENT_COALITION.append(states[7].find(text=True))
        BUNDES_RAT_VOTES.append(states[8].find(text=True))
        AREA_KM_SQUARE.append(states[9].find(text=True))
        POPULATION.append(states[10].find(text=True))
        POP_PER_KM_SQ.append(states[11].find(text=True))
        HUMAN_DEVELOPMENT_INDEX.append(states[12].find(text=True))
        GDP_PER_CAPITA.append(states[14].find(text=True))


# import pandas to convert list to data frame

import pandas as pd
df=pd.DataFrame()
df['STATE']=STATE
df['SINCE']=SINCE
df['CAPITAL']=CAPITAL
df['LEGISLATURE']=LEGISLATURE
df['HEAD_OF_GOVERNMENT']=HEAD_OF_GOVERNMENT
df['GOVERNMENT_COALITION']=GOVERNMENT_COALITION
df['BUNDES_RAT_VOTES']=BUNDES_RAT_VOTES
df['AREA_KM_SQUARE']=AREA_KM_SQUARE
df['POPULATION']=POPULATION
df['POP_PER_KM_SQ']=POP_PER_KM_SQ
df['HUMAN_DEVELOPMENT_INDEX']=HUMAN_DEVELOPMENT_INDEX
df['GDP_PER_CAPITA']=GDP_PER_CAPITA
print(df)
# Out:
#                      STATE   SINCE      CAPITAL  \
# 0        Baden-Württemberg    1952    Stuttgart
# 1                  Bavaria  1949\n       Munich
# 2                   Berlin    1990          –\n
# 3              Brandenburg  1990\n      Potsdam
# 4                   Bremen  1949\n       Bremen
# 5                  Hamburg  1949\n          –\n
# 6                    Hesse  1949\n    Wiesbaden
# 7             Lower Saxony  1949\n      Hanover
# 8   Mecklenburg-Vorpommern  1990\n     Schwerin
# 9             North Rhine-  1949\n   Düsseldorf
# 10    Rhineland-Palatinate  1949\n        Mainz
# 11                Saarland  1957\n  Saarbrücken
# 12                  Saxony  1990\n      Dresden
# 13           Saxony-Anhalt  1990\n    Magdeburg
# 14      Schleswig-Holstein  1949\n         Kiel
# 15               Thuringia  1990\n       Erfurt
#
#                           LEGISLATURE    HEAD_OF_GOVERNMENT  \
# 0        Landtag of Baden-Württemberg  Winfried Kretschmann
# 1                  Landtag of Bavaria          Markus Söder
# 2                    Abgeordnetenhaus        Michael Müller
# 3              Landtag of Brandenburg        Dietmar Woidke
# 4              Bürgerschaft of Bremen  Andreas Bovenschulte
# 5             Bürgerschaft of Hamburg    Peter Tschentscher
# 6                    Landtag of Hesse       Volker Bouffier
# 7             Landtag of Lower Saxony          Stephan Weil
# 8   Landtag of Mecklenburg-Vorpommern      Manuela Schwesig
# 9   Landtag of North Rhine-Westphalia         Armin Laschet
# 10    Landtag of Rhineland-Palatinate           Malu Dreyer
# 11                Landtag of Saarland           Tobias Hans
# 12                  Landtag of Saxony    Michael Kretschmer
# 13           Landtag of Saxony-Anhalt       Reiner Haseloff
# 14      Landtag of Schleswig-Holstein        Daniel Günther
# 15               Landtag of Thuringia          Bodo Ramelow
#
#        GOVERNMENT_COALITION BUNDES_RAT_VOTES AREA_KM_SQUARE    POPULATION  \
# 0                    Greens              6\n       35,752\n  11,100,394\n
# 1                       CSU              6\n       70,552\n  13,124,737\n
# 2                       SPD              4\n          892\n   3,669,491\n
# 3        SPD, CDU, Greens\n              4\n       29,479\n   2,521,893\n
# 4   SPD, Greens, The Left\n              3\n          419\n     681,202\n
# 5             SPD, Greens\n              3\n          755\n   1,847,253\n
# 6             CDU, Greens\n              5\n       21,115\n   6,288,080\n
# 7                SPD, CDU\n              6\n       47,609\n   7,993,448\n
# 8                SPD, CDU\n              3\n       23,180\n   1,609,675\n
# 9                CDU, FDP\n              6\n       34,085\n  17,932,651\n
# 10                    SPD,               4\n       19,853\n   4,084,844\n
# 11               CDU, SPD\n              3\n        2,569\n     990,509\n
# 12       CDU, Greens, SPD\n              4\n       18,416\n   4,077,937\n
# 13       CDU, SPD, Greens\n              4\n       20,446\n   2,208,321\n
# 14       CDU, Greens, FDP\n              4\n       15,799\n   2,896,712\n
# 15  The Left, SPD, Greens\n              4\n       16,172\n   2,143,145\n
#
#    POP_PER_KM_SQ HUMAN_DEVELOPMENT_INDEX GDP_PER_CAPITA
# 0          310\n                 0.953\n       47,290\n
# 1          185\n                 0.947\n       48,323\n
# 2        4,086\n                 0.950\n       41,967\n
# 3           85\n                 0.914\n       29,541\n
# 4        1,630\n                 0.951\n       49,215\n
# 5        2,439\n                 0.975\n       66,879\n
# 6          297\n                 0.949\n       46,923\n
# 7          168\n                 0.922\n       38,423\n
# 8           69\n                 0.910\n       28,940\n
# 9          526\n                 0.936\n       39,678\n
# 10         206\n                 0.928\n       35,457\n
# 11         386\n                 0.931\n       36,684\n
# 12         221\n                 0.930\n       31,453\n
# 13         108\n                 0.908\n       28,800\n
# 14         183\n                 0.920\n       33,712\n
# 15         133\n                 0.921\n       29,883\n

# %% [markdown]
# ### JSON
#
# in these next two example we will read and write a JSON parsed file format.

# %%
import json
json_data="""{"name": "Zophie", "isCat": true, "miceCaught": 0, "napsTaken": 37.5, "felineIQ": null}"""

print(json.loads(json_data))
# Out:
# {'name': 'Zophie', 'isCat': True, 'miceCaught': 0, 'napsTaken': 37.5, 'felineIQ': None}

# %%
import json
pythonValue = {'isCat': True, 'miceCaught': 0, 'name': 'Zophie','felineIQ': None}
json_data = json.dumps(pythonValue)
print(json_data)
# Out:
# {"isCat": true, "miceCaught": 0, "name": "Zophie", "felineIQ": null}

# %%
import requests
import json


# get when the space ship will pass through Newyork

def getNextTimeList(parameters):
    response_time = requests.get("http://api.open-notify.org/iss-pass.json",params=parameters)

    data_time = json.loads(response_time.text)

    response_final = data_time['response']
    total_num_passes = len(response_final)

    response_time_list = []
    for i in response_final:
        response_time_list.append(i['risetime'])

    return (total_num_passes, response_time_list)


#parameters_newyork = {"lat": 40.71, "lon": -74}

#(num_passes_ny, time_list_ny) = getNextTimeList(parameters_newyork)

parameters_regensburg = {"lat": 49.0145, "lon": 12.1009}
(num_passes_rgb, time_list_rgb) = getNextTimeList(parameters_regensburg)


# # Get the response from the API endpoint.
response = requests.get("http://api.open-notify.org/astros.json")
response_astro = json.loads(response.text)
num_astro_space = response_astro["number"]
print(num_astro_space)

astro_names = response_astro["people"]
astro_name_list = []

for name in astro_names:
    astro_name_list.append(name['name'])

print(astro_name_list)
# Out:
# 7
# ['Sergey Ryzhikov', 'Kate Rubins', 'Sergey Kud-Sverchkov', 'Mike Hopkins', 'Victor Glover', 'Shannon Walker', 'Soichi Noguchi']

# %% [markdown]
# ### XML
#
# In this example we will read an xml file format.
#
# Now lets parse some XML data. Our xml file has the following entries:
#
# <?xml version="1.0"?>
# <company>
# 	<name>ABC</name>
# 	<staff id="123">
# 		<name>Andy</name>
# 		<expense>200</expense>
# 	</staff>
# 	<staff id="324">
# 		<name>Mike</name>
# 		<expense>300</expense>
# 	</staff>
# 	<staff id="567">
# 		<name>Chris</name>
# 		<expense>400</expense>
# 	</staff>
# </company>
#
# We will start of with the following basic parse. More Information can be obtained from https://docs.python.org/3/library/xml.etree.elementtree.html

# %%
import xml.etree.ElementTree as ET
tree = ET.parse("data/test.xml")
root = tree.getroot()
print (root.tag)
# Out:
# company

# %%
from xml.dom import minidom

#import pandas as pd

doc = minidom.parse("data/test.xml")

# doc.getElementsByTagName returns NodeList
name = doc.getElementsByTagName("name")[0]
print(name.firstChild.data)

staffs = doc.getElementsByTagName("staff")
for staff in staffs:
        sid = staff.getAttribute("id")
        name = staff.getElementsByTagName("name")[0]
        expense = staff.getElementsByTagName("expense")[0]
        print("id:%s, name:%s, expense:%s" %
              (sid, name.firstChild.data, expense.firstChild.data))
# Out:
# ABC
# id:123, name:Andy, expense:200
# id:324, name:Mike, expense:300
# id:567, name:Chris, expense:400
