# %% [markdown]
# # Lukas Varga

# %% [markdown]
# ## matplotlib Programming Activity
#
#
# For this exercise, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# ![Image 1](images/company_sales_data.png)
#
# Use the following CSV file located in the data folder in this jupyter activity for this exercise. Read this file using Pandas or NumPy or using in-built matplotlib function.
#
# This exercise contains ten questions. The solution provided for each issue. Each question includes a specific Matplotlib topic you need to learn, When you complete each issue you get more familiar with Data data visualization using matplotlib.

# %% [markdown]
# ## Exercise 1: Read Total profit of all months and show it using a line plot
#
# In this activity your will provide the total profit data provided for each month. The generated line plot must include the following properties: –
#
# X label name = Month Number
# Y label name = Total profit
# The line plot graph should look like this.
#
# ![Image 1](images/e1.png)

# %%
# Excercise 1

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/company_sales_data.csv")
x = data["month_number"]
y = data["total_profit"]
plt.plot(x,y)

#labels
plt.xlabel("Month number")
plt.ylabel("Sold units number")
plt.title("Company profit per month")

#limits and ticks
plt.xticks(x)
plt.yticks(np.arange(100000, 500001, 100000))
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 2: Get Total profit of all months and show line plot with the following Style properties
#
# Generated line plot must include following Style properties:
#
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this.
# ![Image 1](images/e2.png)

# %%
# Excercise 2

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/company_sales_data.csv")
x = data["month_number"]
y = data["total_profit"]

#formatting curve
plt.plot(x,y,'--o',color="red",markerfacecolor="black",linewidth=3.0,label = "Profit data of last year")

#labels
plt.xlabel("Month number")
plt.ylabel("Sold units number")
plt.title("Company Sales data of last year")

#limits and ticks
plt.xticks(x)
plt.yticks(np.arange(100000, 500001, 100000))

#legend
plt.legend(loc="lower right")
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 3: Read all product sales data and show it  using a multiline plot
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# The graph should look like this.
#
# ![Image3](images/e3.png)

# %%
# Excercise 3

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/company_sales_data.csv")
x = data["month_number"]

#setting data
t1 = data["facecream"]
t2 = data["facewash"]
t3 = data["toothpaste"]
t4 = data["bathingsoap"]
t5 = data["shampoo"]
t6 = data["moisturizer"]

#creating plots
plt.plot(x,t1,'-o',linewidth=3.0,label = "Face cream Sales Data")
plt.plot(x,t2,'-o',linewidth=3.0,label = "Face wash Sales Data")
plt.plot(x,t3,'-o',linewidth=3.0,label = "Tooth paste Sales Data")
plt.plot(x,t4,'-o',linewidth=3.0,label = "Bathing soap Sales Data")
plt.plot(x,t5,'-o',linewidth=3.0,label = "Shampoo Sales Data")
plt.plot(x,t6,'-o',linewidth=3.0,label = "Moisturizer Sales Data")

#labels
plt.xlabel("Month number")
plt.ylabel("Sales units in number")
plt.title("Sales data")

#limits and ticks
plt.ylim((1000,18000))
plt.xticks(x)

#legend
plt.legend(loc="upper left")
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 4: Read toothpaste sales data of each month and show it using a scatter plot
#
# Also, add a grid in the plot. gridline style should “–“.
#
# The scatter plot should look like this.
#
# ![Image 4](images/e4.png)

# %%
# Excercise 4

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/company_sales_data.csv")
x = data["month_number"]
y = data["toothpaste"]

#formatting curve
plt.scatter(x,y,color="royalblue",label="Tooth paste Sales Data")
plt.grid(linestyle="--")

#labels
plt.xlabel("Month number")
plt.ylabel("Number of units sold")
plt.title("Tooth paste Sales Data")

#limits and ticks
plt.xticks(x)

#legend
plt.legend(loc="upper left")
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 5: Read face cream and facewash product sales data and show it using the bar chart
#
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this.
#
# ![Image 5](images/e5.png)

# %%
# Excercise 5

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#read data
data = pd.read_csv("data/company_sales_data.csv")
x=data["month_number"]
t1=data["facecream"]
t2=data["facewash"]

#creating plot
width = 0.35
fig, ax = plt.subplots()
barT1 = ax.bar(x - width/2, t1, width, label='Face cream sales data')
barT2 = ax.bar(x + width/2, t2, width, label='Face Wash sales data')

#labels
ax.set_xlabel("Month number")
ax.set_ylabel("Sales units in number")
ax.set_title("Facewash and facecream sales data")
ax.grid(linestyle="--")

#ticks and limits
ax.set_xticks(x)

#legend
ax.legend(loc="upper left")
plt.show()


#end code

# %% [markdown]
# ## Exercise Question 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# The bar chart should look like this.
#
# ![image 6](images/e6.png)

# %%
# Excercise 6

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#read data
data = pd.read_csv("data/company_sales_data.csv")
x=data["month_number"]
y=data["bathingsoap"]

#creating plot
fig, ax = plt.subplots()
bar = ax.bar(x, y, label='Face cream sales data')

#labels
ax.set_xlabel("Month number")
ax.set_ylabel("Sales units in number")
ax.set_title("Bathingsoap Sales Data")
ax.grid(linestyle="--")

#ticks and limits
ax.set_xticks(x)
plt.show()

#save to file
plt.savefig("data/bathing_soap.png")

#end code

# %% [markdown]
# ## Exercise Question 7: Read the total profit of each month and show it using the histogram to see most common profit ranges
#
# The histogram should look like this.
#
# ![image 7](images/e7.png)

# %%
# Excercise 7

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#data
data = pd.read_csv("data/company_sales_data.csv")
x = data["total_profit"]

#plot
plt.hist(x,bins=[150000,175000,200000,225000,250000,300000,350000],label="Profit data")

#labels
ax.set_xlabel("profit range in dollar")
ax.set_ylabel("Actual profit in dollar")
ax.set_title("Profit data")

#legend
plt.legend(loc="upper left")
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this.
#
# ![Image 8](images/e8.png)

# %%
# Excercise 8

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#read data
df = pd.read_csv("data/company_sales_data.csv")
data=[]
data.append(df["facecream"])
data.append(df["facewash"])
data.append(df["toothpaste"])
data.append(df["bathingsoap"])
data.append(df["shampoo"])
data.append(df["moisturizer"])

#sum units of all kinds of gods
sums=[]
for i in data:
    sums.append(i.sum())

#total number of units
total=0
for i in range(len(sums)):
    total+=sums[i]

#make percentage
perc=[]
for i in sums:
    result = i/total
    perc.append(result)
    
#make dictionary
res={}
for i in range(len(data)):
    res[data[i].name] = perc[i]
    
#plot
plt.pie(list(res.values()),labels=res.keys(), autopct='%1.1f%%', shadow=False)

#labels
plt.title("Sales Data")

#legend
plt.legend(loc="lower right",bbox_to_anchor=(1.25, 0))
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# The Subplot should look like this.
#
# ![image 9](images/e9.png)

# %%
# Excercise 9

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#data
df = pd.read_csv("data/company_sales_data.csv")
x = df["month_number"]
t1=df["bathingsoap"]
t2=df["facewash"]

#plots
fig = plt.figure()

ax1 = fig.add_subplot(211)
ax1.plot(x,t1,"-o",color="black",linewidth=2.0)
ax1.set_title("Sales data of a Bathingsoap")
ax1.set_xticks([])

ax2 = fig.add_subplot(212)
ax2.plot(x,t2,"-o",color="red",linewidth=2.0)
ax2.set_title("Sales data of a Facewash")
ax2.set_xticks(df["month_number"])
ax2.set_xlabel("Month Number")
ax2.set_ylabel("Sale units in number")
plt.show()

#end code

# %% [markdown]
# ## Exercise Question 10: Read all product sales data and show it using the stack plot
#
# The Stack plot should look like this.
#
# ![Image 10](images/e10.png)

# %%
# Excercise 10

#Start Code 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#read data
df = pd.read_csv("data/company_sales_data.csv")
x=df["month_number"]
data=[]
data.append(df["facecream"])
data.append(df["facewash"])
data.append(df["toothpaste"])
data.append(df["bathingsoap"])
data.append(df["shampoo"])
data.append(df["moisturizer"])

#plot
colors=["purple","aqua","red","black","darkgreen","gold"]
for i in range(len(data)):
    plt.plot([],[],color=colors[i],label=data[i].name)
plt.stackplot(x,data[0],data[1],data[2],data[3],data[4],data[5],colors = colors)

#labels and legend
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('All product sales data using stack plot')
plt.legend(loc="upper left")
plt.show()

#end code
